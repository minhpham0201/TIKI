# %%
import pandas as pd
import json
import requests 
import time
import random
import tqdm
from urllib.parse import urlparse

# %%
# cookies = {
#     '_trackity' : '74634137-8702-8b12-fe42-46a46a2a2573',
#     'TOKENS' : '{%22access_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22%2C%22expires_in%22:157680000%2C%22expires_at%22:1844582643238%2C%22guest_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22}',
#     'delivery_zone' : 'Vk4wMzkwMDYwMDE=',
#     '_gid' : 'GA1.2.1038835342.1686902648',
#     'tiki_client_id' : '1000198359.1686902648',
#     '_gcl_au' : '1.1.712561686.1686902651',
#     '_fbp' : 'fb.1.1686902651246.1147493922',
#     '_hjFirstSeen' : '1', 
#     '_hjIncludedInSessionSample_522327' : '0', 
#     '_hjSession_522327':'eyJpZCI6IjRmYmI5NDEzLTc1MzAtNDA3Yy1iYTMyLTYzZTI4Y2MzZTA5NSIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMTksImluU2FtcGxlIjpmYWxzZX0=',
#     '_hjAbsoluteSessionInProgress' : '0',
#     '__uidac' : 'b0f5fe8e77ade31f60d53549702ce9ac',
#     '__iid' : '749', '__iid' : '749', '__su' : '0',
#     '__su':'0', '__RC' : '5', '__R' : '3',
#     '_hjSessionUser_522327':'eyJpZCI6IjFiMTI5YzM0LWE2NTItNWZmOC05NmEzLTFhY2JlOTMwZTViYyIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMDIsImV4aXN0aW5nIjp0cnVlfQ==',
#     '__tb':'0', 
#     '__IP' : '712479999',
#     'TIKI_RECOMMENDATION' : '40be1840f8c66757ac3812da38a02d7b',
#     'TKSESSID':'cf67caae16e0362971a2fe1e3367c12e',
#     '_bs':'c4f97c3c-1a3b-0d7a-f2dd-a0a3516f6617',
#     '_gat' : '1',
#     '_ga': 'GA1.2.1000198359.1686902648',
#     '__uif' :'__uid%3A3569195332985378685%7C__ui%3A1%252C5%7C__create%3A1669195332',
#     'cto_bundle':'5mSn7195TEwza3VCTEZZTk9HdWw1cSUyQkM2dGRGV0ZtUlRua1NvRjV5S2phc096S1lIVlJySjlmZkdqUVNScWNMbEdoamc0bE82czlSR0lYS1pKMU1pNk40U2lnQSUyRiUyQlBGbFJ5MXBwUUtwOW1oVUoxQm9hY1olMkZ1ZWplRzhUdThiZnNqeExlMnkyV1NyMnpBNmlJdXAwRFZvb2FsQSUzRCUzRA',
#     'amp_99d374':'Rz66229-5rdmltAOjfyUvJ...1h31jn9b2.1h31k9l0t.2j.5e.81',
#     '_ga_GSD4ETCY1D':'GS1.1.1686902651.1.1.1686903252.28.0.0'
# }


headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept':'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8,th;q=0.7,zh-CN;q=0.6,zh;q=0.5',
    'X-Guest-Token': 'Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2',
    'Connection' : 'keep-alive',
    'TE': 'Trailers'
}

# %%
# 'https://tiki.vn/kinh-mat-nu/c5394',
#             'https://tiki.vn/kinh-mat-nam/c5410',
#             'https://tiki.vn/gong-kinh-nam/c8382',
#             'https://tiki.vn/gong-kinh-nu/c8384',
#             'https://tiki.vn/phu-kien-kinh/c11843',

# %%
list_url = [
            'https://tiki.vn/non-rong-vanh-nu/c49668',
            'https://tiki.vn/vo-ngan-nu/c49672',
            'https://tiki.vn/vo-dai-nu/c49674',
            'https://tiki.vn/khan-choang-khan-tay-nu/c5402',
            'https://tiki.vn/cot-toc/c49678',
            'https://tiki.vn/cai-toc/c49680',
            'https://tiki.vn/phu-kien-toc-khac/c49688',
            'https://tiki.vn/that-lung-nu-ban-nho/c49692',
            'https://tiki.vn/phu-kien-cuoi/c5400',
            'https://tiki.vn/cai-ao/c15118',
            'https://tiki.vn/khan-gang-tay-nam/c8343',
            'https://tiki.vn/day-that-lung-day-nit/c5339'
]

page_error = []
price_range = [
    '500,15000', '15001,30000', '30001,50000', '50001,80000', '80001,150000',
    '150001,250000', '250001,350000', '350001,550000', '550000, 100000000'
                ]
list_page_50 = []

for url in list_url:
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.split('/')

    category_name = path_segments[1]
    category_id = path_segments[2][1:]
    product_data = []
    for price in price_range:
        params = {
            'limit': '40',
            'include': 'advertisement',
            'aggregations': '2',
            'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
            'category': category_id,
            'page': '1',
            'urlKey': category_name,
            'price': price
        }
        
        response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

        if response.status_code == 200:
            response_json = response.json()
            last_page = response_json.get('paging', {}).get('last_page')
            print('CATEGORY', category_name, price)
            print('total pages', last_page)

            if last_page == 50:
                list_page_50.append([category_name, price])
                continue
            else:
                for i in range(1, last_page + 1):
                    params['page'] = i
                    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers,params=params)

                    if response.status_code == 200:
                        print('request done page', i)
                        response_json = response.json()
                        for record in response_json.get('data', []):
                            product_id = record.get('id')
                            product_data.append({'product_id': product_id, 'category_name': category_name,
                                                 'max_page': last_page})
                    else:
                        print('cannot request page', i)
                        page_error.append([category_name,category_id,price,i])
                    time.sleep(random.randrange(3, 10))

    product_df = pd.DataFrame(product_data, columns=['product_id', 'category_name', 'max_page'])
    output_file_name = f'PHU-KIEN-THOI-TRANG-50-{category_name}.csv'
    product_df.to_csv(output_file_name, index=False)
# Out:
# CATEGORY non-rong-vanh-nu 500,15000
# total pages 1
# request done page 1
# CATEGORY non-rong-vanh-nu 15001,30000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY non-rong-vanh-nu 30001,50000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY non-rong-vanh-nu 50001,80000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY non-rong-vanh-nu 80001,150000
# total pages 18
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# CATEGORY non-rong-vanh-nu 150001,250000
# total pages 17
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# CATEGORY non-rong-vanh-nu 250001,350000
# total pages 3
# request done page 1
# request done page 2
# request done page 3
# CATEGORY non-rong-vanh-nu 350001,550000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY vo-ngan-nu 500,15000
# total pages 16
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# CATEGORY vo-ngan-nu 15001,30000
# total pages 16
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# CATEGORY vo-ngan-nu 30001,50000
# total pages 23
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# cannot request page 10
# request done page 11
# cannot request page 12
# request done page 13
# cannot request page 14
# request done page 15
# cannot request page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# CATEGORY vo-ngan-nu 50001,80000
# total pages 20
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# CATEGORY vo-ngan-nu 80001,150000
# total pages 21
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# cannot request page 9
# request done page 10
# request done page 11
# request done page 12
# cannot request page 13
# request done page 14
# request done page 15
# cannot request page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# CATEGORY vo-ngan-nu 150001,250000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# CATEGORY vo-ngan-nu 250001,350000
# total pages 1
# request done page 1
# CATEGORY vo-ngan-nu 350001,550000
# total pages 1
# request done page 1
# CATEGORY vo-dai-nu 500,15000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY vo-dai-nu 15001,30000
# total pages 17
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# CATEGORY vo-dai-nu 30001,50000
# total pages 16
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# CATEGORY vo-dai-nu 50001,80000
# total pages 14
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# CATEGORY vo-dai-nu 80001,150000
# total pages 18
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# CATEGORY vo-dai-nu 150001,250000
# total pages 7
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# CATEGORY vo-dai-nu 250001,350000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY vo-dai-nu 350001,550000
# total pages 1
# request done page 1
# CATEGORY khan-choang-khan-tay-nu 500,15000
# total pages 1
# request done page 1
# CATEGORY khan-choang-khan-tay-nu 15001,30000
# total pages 5
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# CATEGORY khan-choang-khan-tay-nu 30001,50000
# total pages 6
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY khan-choang-khan-tay-nu 50001,80000
# total pages 12
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# CATEGORY khan-choang-khan-tay-nu 80001,150000
# total pages 30
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# CATEGORY khan-choang-khan-tay-nu 150001,250000
# total pages 12
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# CATEGORY khan-choang-khan-tay-nu 250001,350000
# total pages 3
# request done page 1
# request done page 2
# request done page 3
# CATEGORY khan-choang-khan-tay-nu 350001,550000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY cot-toc 500,15000
# total pages 46
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# request done page 41
# request done page 42
# request done page 43
# request done page 44
# request done page 45
# request done page 46
# CATEGORY cot-toc 15001,30000
# total pages 39
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# cannot request page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# CATEGORY cot-toc 30001,50000
# total pages 28
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# CATEGORY cot-toc 50001,80000
# total pages 17
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# cannot request page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# CATEGORY cot-toc 80001,150000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY cot-toc 150001,250000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# CATEGORY cot-toc 250001,350000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY cot-toc 350001,550000
# total pages 1
# request done page 1
# CATEGORY cai-toc 500,15000
# total pages 8
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# CATEGORY cai-toc 15001,30000
# total pages 17
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# cannot request page 10
# cannot request page 11
# request done page 12
# cannot request page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# CATEGORY cai-toc 50001,80000
# total pages 8
# request done page 1
# request done page 2
# cannot request page 3
# request done page 4
# request done page 5
# cannot request page 6
# request done page 7
# request done page 8
# CATEGORY cai-toc 150001,250000
# total pages 3
# request done page 1
# request done page 2
# request done page 3
# CATEGORY cai-toc 250001,350000
# total pages 1
# request done page 1
# CATEGORY cai-toc 350001,550000
# total pages 1
# request done page 1
# CATEGORY phu-kien-toc-khac 500,15000
# total pages 27
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# cannot request page 20
# request done page 21
# cannot request page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# CATEGORY phu-kien-toc-khac 15001,30000
# total pages 41
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# request done page 41
# CATEGORY phu-kien-toc-khac 30001,50000
# total pages 34
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# CATEGORY phu-kien-toc-khac 50001,80000
# total pages 23
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# cannot request page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# CATEGORY phu-kien-toc-khac 80001,150000
# total pages 12
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# CATEGORY phu-kien-toc-khac 150001,250000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# CATEGORY phu-kien-toc-khac 250001,350000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY phu-kien-toc-khac 350001,550000
# total pages 1
# request done page 1
# CATEGORY that-lung-nu-ban-nho 500,15000
# total pages 1
# request done page 1
# CATEGORY that-lung-nu-ban-nho 15001,30000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY that-lung-nu-ban-nho 30001,50000
# total pages 6
# request done page 1
# request done page 2
# cannot request page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY that-lung-nu-ban-nho 50001,80000
# total pages 12
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# cannot request page 5
# request done page 6
# request done page 7
# request done page 8
# cannot request page 9
# request done page 10
# cannot request page 11
# request done page 12
# CATEGORY that-lung-nu-ban-nho 80001,150000
# total pages 17
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# CATEGORY that-lung-nu-ban-nho 150001,250000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY that-lung-nu-ban-nho 250001,350000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# CATEGORY that-lung-nu-ban-nho 350001,550000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# cannot request page 4
# CATEGORY phu-kien-cuoi 500,15000
# total pages 7
# cannot request page 1
# request done page 2
# request done page 3
# cannot request page 4
# cannot request page 5
# request done page 6
# request done page 7
# CATEGORY phu-kien-cuoi 30001,50000
# total pages 15
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# CATEGORY phu-kien-cuoi 50001,80000
# total pages 23
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# CATEGORY phu-kien-cuoi 80001,150000
# total pages 34
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# CATEGORY phu-kien-cuoi 150001,250000
# total pages 20
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# CATEGORY phu-kien-cuoi 250001,350000
# total pages 10
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# CATEGORY phu-kien-cuoi 350001,550000
# total pages 8
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# CATEGORY cai-ao 500,15000
# total pages 6
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY cai-ao 15001,30000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY cai-ao 30001,50000
# total pages 14
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# CATEGORY cai-ao 50001,80000
# total pages 19
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# CATEGORY cai-ao 80001,150000
# total pages 30
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# CATEGORY cai-ao 150001,250000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY cai-ao 250001,350000
# total pages 5
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# CATEGORY cai-ao 350001,550000
# total pages 6
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY khan-gang-tay-nam 500,15000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY khan-gang-tay-nam 15001,30000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# CATEGORY khan-gang-tay-nam 30001,50000
# total pages 8
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# CATEGORY khan-gang-tay-nam 50001,80000
# total pages 13
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# CATEGORY khan-gang-tay-nam 80001,150000
# total pages 21
# request done page 1
# request done page 2
# cannot request page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# CATEGORY khan-gang-tay-nam 150001,250000
# total pages 21
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# CATEGORY khan-gang-tay-nam 250001,350000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# CATEGORY khan-gang-tay-nam 350001,550000
# total pages 3
# request done page 1
# request done page 2
# request done page 3
# CATEGORY day-that-lung-day-nit 500,15000
# total pages 1
# request done page 1
# CATEGORY day-that-lung-day-nit 15001,30000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY day-that-lung-day-nit 30001,50000
# total pages 6
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY day-that-lung-day-nit 50001,80000
# total pages 11
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# CATEGORY day-that-lung-day-nit 80001,150000
# total pages 25
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# CATEGORY day-that-lung-day-nit 150001,250000
# total pages 35
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# CATEGORY day-that-lung-day-nit 250001,350000
# total pages 21
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# cannot request page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# cannot request page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# CATEGORY day-that-lung-day-nit 350001,550000
# total pages 16
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16

# %%
print(list_page_50)
# Out:
# []

# %%
print(page_error)
# Out:
# [['vo-ngan-nu', '49672', '30001,50000', 10], ['vo-ngan-nu', '49672', '30001,50000', 12], ['vo-ngan-nu', '49672', '30001,50000', 14], ['vo-ngan-nu', '49672', '30001,50000', 16], ['vo-ngan-nu', '49672', '80001,150000', 9], ['vo-ngan-nu', '49672', '80001,150000', 13], ['vo-ngan-nu', '49672', '80001,150000', 16], ['cot-toc', '49678', '15001,30000', 30], ['cot-toc', '49678', '50001,80000', 11], ['cai-toc', '49680', '15001,30000', 10], ['cai-toc', '49680', '15001,30000', 11], ['cai-toc', '49680', '15001,30000', 13], ['cai-toc', '49680', '50001,80000', 3], ['cai-toc', '49680', '50001,80000', 6], ['phu-kien-toc-khac', '49688', '500,15000', 20], ['phu-kien-toc-khac', '49688', '500,15000', 22], ['phu-kien-toc-khac', '49688', '50001,80000', 18], ['that-lung-nu-ban-nho', '49692', '30001,50000', 3], ['that-lung-nu-ban-nho', '49692', '50001,80000', 5], ['that-lung-nu-ban-nho', '49692', '50001,80000', 9], ['that-lung-nu-ban-nho', '49692', '50001,80000', 11], ['that-lung-nu-ban-nho', '49692', '350001,550000', 4], ['phu-kien-cuoi', '5400', '500,15000', 1], ['phu-kien-cuoi', '5400', '500,15000', 4], ['phu-kien-cuoi', '5400', '500,15000', 5], ['khan-gang-tay-nam', '8343', '80001,150000', 3], ['day-that-lung-day-nit', '5339', '250001,350000', 9], ['day-that-lung-day-nit', '5339', '250001,350000', 14]]

# %%
product_data_error = []
if len(page_error) != 0 :
    for i in range(len(page_error)):
        error_page_params = {
                    'limit': '40',
                    'include': 'advertisement',
                    'aggregations': '2',
                    'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
                    'category': page_error[i][1],
                    'page': str(page_error[i][3]),
                    'urlKey': page_error[i][0],
                    'price': page_error[i][2]
                }

        response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers,params=error_page_params)

        if response.status_code == 200:
            print('request done page', page_error[i][0], page_error[i][3], page_error[i][2])
            response_json = response.json()
            for record in response_json.get('data', []):
                product_id = record.get('id')
                product_data_error.append({'product_id': product_id, 'category_name': page_error[i][0]})

        time.sleep(random.randrange(3, 10))

    product_df = pd.DataFrame(product_data_error, columns=['product_id', 'category_name'])
    output_file_name = f'PHU-KIEN-THOI-TRANG-50-ERROR.csv'
    product_df.to_csv(output_file_name, index=False)
# Out:
# request done page vo-ngan-nu 10 30001,50000
# request done page vo-ngan-nu 12 30001,50000
# request done page vo-ngan-nu 14 30001,50000
# request done page vo-ngan-nu 16 30001,50000
# request done page vo-ngan-nu 9 80001,150000
# request done page vo-ngan-nu 13 80001,150000
# request done page vo-ngan-nu 16 80001,150000
# request done page cot-toc 30 15001,30000
# request done page cot-toc 11 50001,80000
# request done page cai-toc 10 15001,30000
# request done page cai-toc 11 15001,30000
# request done page cai-toc 13 15001,30000
# request done page cai-toc 3 50001,80000
# request done page cai-toc 6 50001,80000
# request done page phu-kien-toc-khac 20 500,15000
# request done page phu-kien-toc-khac 22 500,15000
# request done page phu-kien-toc-khac 18 50001,80000
# request done page that-lung-nu-ban-nho 3 30001,50000
# request done page that-lung-nu-ban-nho 5 50001,80000
# request done page that-lung-nu-ban-nho 11 50001,80000
# request done page that-lung-nu-ban-nho 4 350001,550000
# request done page phu-kien-cuoi 4 500,15000
# request done page khan-gang-tay-nam 3 80001,150000
# request done page day-that-lung-day-nit 9 250001,350000
# request done page day-that-lung-day-nit 14 250001,350000
