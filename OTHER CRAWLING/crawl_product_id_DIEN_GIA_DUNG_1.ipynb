# %%
import pandas as pd
import json
import requests 
import time
import random
import tqdm
from urllib.parse import urlparse

# %%
# cookies = {
#     '_trackity' : '74634137-8702-8b12-fe42-46a46a2a2573',
#     'TOKENS' : '{%22access_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22%2C%22expires_in%22:157680000%2C%22expires_at%22:1844582643238%2C%22guest_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22}',
#     'delivery_zone' : 'Vk4wMzkwMDYwMDE=',
#     '_gid' : 'GA1.2.1038835342.1686902648',
#     'tiki_client_id' : '1000198359.1686902648',
#     '_gcl_au' : '1.1.712561686.1686902651',
#     '_fbp' : 'fb.1.1686902651246.1147493922',
#     '_hjFirstSeen' : '1', 
#     '_hjIncludedInSessionSample_522327' : '0', 
#     '_hjSession_522327':'eyJpZCI6IjRmYmI5NDEzLTc1MzAtNDA3Yy1iYTMyLTYzZTI4Y2MzZTA5NSIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMTksImluU2FtcGxlIjpmYWxzZX0=',
#     '_hjAbsoluteSessionInProgress' : '0',
#     '__uidac' : 'b0f5fe8e77ade31f60d53549702ce9ac',
#     '__iid' : '749', '__iid' : '749', '__su' : '0',
#     '__su':'0', '__RC' : '5', '__R' : '3',
#     '_hjSessionUser_522327':'eyJpZCI6IjFiMTI5YzM0LWE2NTItNWZmOC05NmEzLTFhY2JlOTMwZTViYyIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMDIsImV4aXN0aW5nIjp0cnVlfQ==',
#     '__tb':'0', 
#     '__IP' : '712479999',
#     'TIKI_RECOMMENDATION' : '40be1840f8c66757ac3812da38a02d7b',
#     'TKSESSID':'cf67caae16e0362971a2fe1e3367c12e',
#     '_bs':'c4f97c3c-1a3b-0d7a-f2dd-a0a3516f6617',
#     '_gat' : '1',
#     '_ga': 'GA1.2.1000198359.1686902648',
#     '__uif' :'__uid%3A3569195332985378685%7C__ui%3A1%252C5%7C__create%3A1669195332',
#     'cto_bundle':'5mSn7195TEwza3VCTEZZTk9HdWw1cSUyQkM2dGRGV0ZtUlRua1NvRjV5S2phc096S1lIVlJySjlmZkdqUVNScWNMbEdoamc0bE82czlSR0lYS1pKMU1pNk40U2lnQSUyRiUyQlBGbFJ5MXBwUUtwOW1oVUoxQm9hY1olMkZ1ZWplRzhUdThiZnNqeExlMnkyV1NyMnpBNmlJdXAwRFZvb2FsQSUzRCUzRA',
#     'amp_99d374':'Rz66229-5rdmltAOjfyUvJ...1h31jn9b2.1h31k9l0t.2j.5e.81',
#     '_ga_GSD4ETCY1D':'GS1.1.1686902651.1.1.1686903252.28.0.0'
# }


headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept':'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8,th;q=0.7,zh-CN;q=0.6,zh;q=0.5',
    'X-Guest-Token': 'Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2',
    'Connection' : 'keep-alive',
    'TE': 'Trailers'
}

# %%
list_url = ['https://tiki.vn/noi-dien-cac-loai/c1892',
            'https://tiki.vn/bep-cac-loai/c1885',
            'https://tiki.vn/may-hut-khoi-khu-mui/c4875',
            'https://tiki.vn/lo-vi-song/c2022',
            'https://tiki.vn/lo-nuong-dien/c2023',
            'https://tiki.vn/vi-nuong/c2044',
            'https://tiki.vn/may-xay-may-ep/c2024',
            'https://tiki.vn/binh-dun-sieu-toc/c1931',
            'https://tiki.vn/binh-thuy-dien/c1932',
            'https://tiki.vn/may-pha-ca-phe/c1939',
            'https://tiki.vn/may-lam-kem/c8082',
            'https://tiki.vn/may-lam-sua-dau-nanh/c2025',
            'https://tiki.vn/may-lam-sua-chua/c2026',
            'https://tiki.vn/may-lam-mi-soi/c5363',
            'https://tiki.vn/may-lam-banh/c2315',
            'https://tiki.vn/sieu-sac-thuoc/c1942',
            'https://tiki.vn/may-lam-toi-den/c7239',
            'https://tiki.vn/may-say-chen/c23818',
            'https://tiki.vn/may-say-thuc-pham/c23820',
            'https://tiki.vn/may-hut-chan-khong/c23822',
            'https://tiki.vn/may-han-mieng-tui/c23824',
            'https://tiki.vn/may-cat-thit-dong-lanh/c23826',
            'https://tiki.vn/do-dung-nha-bep-khac/c8728',
            'https://tiki.vn/may-danh-trung/c2108'
            ]

for url in list_url:
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.split('/')

    category_name = path_segments[1]
    category_id = path_segments[2][1:]

    params = {
        'limit':'40',  #uptosize
        'include': 'advertisement',
        'aggregations': '2',
        'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
        'category': category_id,  #change
        'page': '1',
        'urlKey': category_name #change
    }

    product_data = []
    page_error = []
    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)
    last_page = response.json().get('paging').get('last_page')
    print('total pages',last_page)
    print('CATEGORY ', category_name)

    for i in range(1, last_page + 1):
        params['page'] = i
        response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

        if response.status_code == 200:
            print('request done page', i)
            for record in response.json().get('data'):
                product_id = record.get('id')
                product_data.append({'product_id': product_id, 'category_name': category_name, 'max_page': last_page})
        else:
            print('cannot request page',i)
            page_error.append(i)
        time.sleep(random.randrange(3, 10))

    product_df = pd.DataFrame(product_data,columns = ['product_id','category_name'])  
   
    output_file_name = f'DIENGIADUNG-1-{category_name}.csv'
    product_df.to_csv(output_file_name)
# Out:
# total pages 50
# CATEGORY  noi-dien-cac-loai
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# request done page 41
# request done page 42
# request done page 43
# request done page 44
# request done page 45
# request done page 46
# request done page 47
# request done page 48
# request done page 49
# request done page 50
# total pages 50
# CATEGORY  bep-cac-loai
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# request done page 41
# request done page 42
# request done page 43
# request done page 44
# request done page 45
# request done page 46
# request done page 47
# request done page 48
# request done page 49
# request done page 50
# total pages 38
# CATEGORY  may-hut-khoi-khu-mui
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# total pages 10
# CATEGORY  lo-vi-song
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# total pages 17
# CATEGORY  lo-nuong-dien
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# cannot request page 9
# request done page 10
# request done page 11
# request done page 12
# cannot request page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# total pages 7
# CATEGORY  vi-nuong
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# total pages 50
# CATEGORY  may-xay-may-ep
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# cannot request page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# request done page 41
# request done page 42
# request done page 43
# request done page 44
# request done page 45
# request done page 46
# request done page 47
# request done page 48
# request done page 49
# request done page 50
# total pages 37
# CATEGORY  binh-dun-sieu-toc
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# cannot request page 35
# request done page 36
# request done page 37
# total pages 6
# CATEGORY  binh-thuy-dien
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# total pages 25
# CATEGORY  may-pha-ca-phe
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# total pages 2
# CATEGORY  may-lam-kem
# request done page 1
# request done page 2
# total pages 8
# CATEGORY  may-lam-sua-dau-nanh
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# total pages 2
# CATEGORY  may-lam-sua-chua
# request done page 1
# request done page 2
# total pages 1
# CATEGORY  may-lam-mi-soi
# request done page 1
# total pages 9
# CATEGORY  may-lam-banh
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# total pages 5
# CATEGORY  sieu-sac-thuoc
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# total pages 2
# CATEGORY  may-lam-toi-den
# request done page 1
# request done page 2
# total pages 5
# CATEGORY  may-say-chen
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# total pages 3
# CATEGORY  may-say-thuc-pham
# request done page 1
# request done page 2
# request done page 3
# total pages 9
# CATEGORY  may-hut-chan-khong
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# total pages 7
# CATEGORY  may-han-mieng-tui
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# total pages 2
# CATEGORY  may-cat-thit-dong-lanh
# cannot request page 1
# request done page 2
# total pages 36
# CATEGORY  do-dung-nha-bep-khac
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# total pages 17
# CATEGORY  may-danh-trung
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
