# %%
import pandas as pd
import json
import requests 
import time
import random
import tqdm
from urllib.parse import urlparse

# %%
# cookies = {
#     '_trackity' : '74634137-8702-8b12-fe42-46a46a2a2573',
#     'TOKENS' : '{%22access_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22%2C%22expires_in%22:157680000%2C%22expires_at%22:1844582643238%2C%22guest_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22}',
#     'delivery_zone' : 'Vk4wMzkwMDYwMDE=',
#     '_gid' : 'GA1.2.1038835342.1686902648',
#     'tiki_client_id' : '1000198359.1686902648',
#     '_gcl_au' : '1.1.712561686.1686902651',
#     '_fbp' : 'fb.1.1686902651246.1147493922',
#     '_hjFirstSeen' : '1', 
#     '_hjIncludedInSessionSample_522327' : '0', 
#     '_hjSession_522327':'eyJpZCI6IjRmYmI5NDEzLTc1MzAtNDA3Yy1iYTMyLTYzZTI4Y2MzZTA5NSIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMTksImluU2FtcGxlIjpmYWxzZX0=',
#     '_hjAbsoluteSessionInProgress' : '0',
#     '__uidac' : 'b0f5fe8e77ade31f60d53549702ce9ac',
#     '__iid' : '749', '__iid' : '749', '__su' : '0',
#     '__su':'0', '__RC' : '5', '__R' : '3',
#     '_hjSessionUser_522327':'eyJpZCI6IjFiMTI5YzM0LWE2NTItNWZmOC05NmEzLTFhY2JlOTMwZTViYyIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMDIsImV4aXN0aW5nIjp0cnVlfQ==',
#     '__tb':'0', 
#     '__IP' : '712479999',
#     'TIKI_RECOMMENDATION' : '40be1840f8c66757ac3812da38a02d7b',
#     'TKSESSID':'cf67caae16e0362971a2fe1e3367c12e',
#     '_bs':'c4f97c3c-1a3b-0d7a-f2dd-a0a3516f6617',
#     '_gat' : '1',
#     '_ga': 'GA1.2.1000198359.1686902648',
#     '__uif' :'__uid%3A3569195332985378685%7C__ui%3A1%252C5%7C__create%3A1669195332',
#     'cto_bundle':'5mSn7195TEwza3VCTEZZTk9HdWw1cSUyQkM2dGRGV0ZtUlRua1NvRjV5S2phc096S1lIVlJySjlmZkdqUVNScWNMbEdoamc0bE82czlSR0lYS1pKMU1pNk40U2lnQSUyRiUyQlBGbFJ5MXBwUUtwOW1oVUoxQm9hY1olMkZ1ZWplRzhUdThiZnNqeExlMnkyV1NyMnpBNmlJdXAwRFZvb2FsQSUzRCUzRA',
#     'amp_99d374':'Rz66229-5rdmltAOjfyUvJ...1h31jn9b2.1h31k9l0t.2j.5e.81',
#     '_ga_GSD4ETCY1D':'GS1.1.1686902651.1.1.1686903252.28.0.0'
# }


headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept':'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8,th;q=0.7,zh-CN;q=0.6,zh;q=0.5',
    'X-Guest-Token': 'Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2',
    'Connection' : 'keep-alive',
    'TE': 'Trailers'
}

# %%
# https://tiki.vn/hop-dung-thuc-pham/c2225
# https://tiki.vn/tui-mang-boc-thuc-pham/c23134
# https://tiki.vn/hu-lo-dung-gia-vi/c6948
# https://tiki.vn/khay-thau-ro/c9052
# https://tiki.vn/noi-cac-loai/c2136
# https://tiki.vn/chao-cac-loai/c1984
# https://tiki.vn/dao-cac-loai/c2511
# https://tiki.vn/dung-cu-cat-got-bao/c3216
# https://tiki.vn/keo-cac-loai/c27256
# https://tiki.vn/khuon-lam-banh/c23156
# https://tiki.vn/dung-cu-lam-banh-khac/c5454
# https://tiki.vn/ke-nha-bep/c6305
# https://tiki.vn/bep-nuong-vi-nuong/c2849
# https://tiki.vn/than-con-dung-cu-moi-lua/c23184
# https://tiki.vn/chau-voi-rua-chen-bat/c23228
# https://tiki.vn/phu-kien-nha-bep-khac/c2514
# https://tiki.vn/thot-nha-bep/c2512
# https://tiki.vn/binh-giu-nhiet/c1936
# https://tiki.vn/binh-dung-nuoc/c23282
# https://tiki.vn/binh-ly-uong-tra-va-phu-kien/c3990
# https://tiki.vn/binh-ly-uong-ca-phe-va-phu-kien/c23304
# https://tiki.vn/ly-coc-phu-kien-ly/c3177
# https://tiki.vn/dua-muong-nia/c3179
# https://tiki.vn/dung-cu-pha-che/c23322
# https://tiki.vn/hop-khan-giay/c23336
# https://tiki.vn/phu-kien-phong-an-khac/c23340
# https://tiki.vn/to-chen-dia/c3178
# https://tiki.vn/bo-ga-ra-drap/c23346
# https://tiki.vn/chan-men-va-phu-kien/c23352
# https://tiki.vn/goi-cac-loai/c23362
# https://tiki.vn/nem/c23376
# https://tiki.vn/sofa-salon-va-phu-kien/c23576
# https://tiki.vn/ban-ghe-cac-loai/c12590
# https://tiki.vn/ke-tu/c23588
# https://tiki.vn/rem-man-cua/c23592
# https://tiki.vn/noi-that-phong-khach-khac/c23596
# https://tiki.vn/ban-trang-diem/c23600
# https://tiki.vn/tu/c23622
# https://tiki.vn/noi-that-phong-ngu-khac/c23634
# https://tiki.vn/ban-ghe/c23642
# https://tiki.vn/ban-ghe/c23642
# https://tiki.vn/ban-ghe-lam-viec/c4381
# https://tiki.vn/ban-ghe-hoc-sinh/c4380
# https://tiki.vn/tu-ke-sach/c23658
# https://tiki.vn/noi-that-phong-hoc-lam-viec-khac/c23660
# https://tiki.vn/noi-that-khac/c23678
# https://tiki.vn/tranh-canvas/c27230
# https://tiki.vn/tranh-theu/c27232
# https://tiki.vn/cac-loai-tranh-khac/c27240
# https://tiki.vn/nen-trang-tri-phu-kien/c23800
# https://tiki.vn/mo-hinh-tuong-trang-tri/c27212
# https://tiki.vn/trang-tri-nha-cua-khac/c27214
# https://tiki.vn/linh-vat-phong-thuy/c23102
# https://tiki.vn/da-cay-phong-thuy/c23104
# https://tiki.vn/vat-pham-phong-thuy-khac/c23112

# %%
'https://tiki.vn/am-dun-nuoc/c1934',
            'https://tiki.vn/dung-cu-nau-an/c23122',
            'https://tiki.vn/xung-hap/c23126',
            'https://tiki.vn/gia-dat-dao/c23154',
            'https://tiki.vn/dung-cu-mai-dao/c4342',
            'https://tiki.vn/keo-nha-bep/c3213',
            'https://tiki.vn/khay-nuong-banh/c23162',

# %%
list_url = [
            'https://tiki.vn/dung-cu-do-luong/c23168',
            'https://tiki.vn/can-nha-bep/c3515',
            'https://tiki.vn/dung-cu-xay-gia/c2513',
            'https://tiki.vn/dung-cu-ep-trai-cay-vat-cam/c23210',
            'https://tiki.vn/mang-nhom-giay-bac-boc-thuc-pham/c23216',
            'https://tiki.vn/khay-khuon-lam-da/c23220',
            'https://tiki.vn/mieng-rua-chen-cha-noi/c23024',
            'https://tiki.vn/binh-ca-dung-nuoc/c3991',
            'https://tiki.vn/binh-loc/c23286',
            'https://tiki.vn/loi-loc/c23288',
            'https://tiki.vn/thiet-bi-loc/c23290',
            'https://tiki.vn/gat-tan/c23334',
            'https://tiki.vn/khay-mut/c23338',
            'https://tiki.vn/ruot-goi/c23366',
            'https://tiki.vn/vo-goi/c23370',
            'https://tiki.vn/phu-kien-nem/c23388',
            'https://tiki.vn/chieu/c23392',
            'https://tiki.vn/vong/c23394',
            'https://tiki.vn/sofa-salon-va-phu-kien/c23576',
            'https://tiki.vn/ban-ghe-cac-loai/c12590',
            'https://tiki.vn/ke-tu/c23588',
            'https://tiki.vn/rem-man-cua/c23592',
            'https://tiki.vn/noi-that-phong-khach-khac/c23596',
            'https://tiki.vn/dem-ngoi/c23374',
            'https://tiki.vn/ghe-cac-loai/c23540',
            'https://tiki.vn/guong/c23630',
            'https://tiki.vn/ke-tu/c23646',
            'https://tiki.vn/quay-bar/c23648',
            'https://tiki.vn/noi-that-phong-an-khac/c23652',
            'https://tiki.vn/ke-tu/c23646',
            'https://tiki.vn/quay-bar/c23648',
            'https://tiki.vn/noi-that-phong-an-khac/c23652',
            'https://tiki.vn/ban-vi-tinh/c23656',
            'https://tiki.vn/ban-tre-em/c23664',
            'https://tiki.vn/giuong-ngu-tre-em/c23666',
            'https://tiki.vn/ghe-tre-em/c23668',
            'https://tiki.vn/thung-dung-do-choi/c23670',
            'https://tiki.vn/noi-that-tre-em-khac/c23672',
            'https://tiki.vn/decal-giay-dan-tuong/c3710',
            'https://tiki.vn/decal-giay-dan-kinh/c23778',
            'https://tiki.vn/dong-ho-de-ban/c2140',
            'https://tiki.vn/thap-dong-ho/c23726',
            'https://tiki.vn/dong-ho-treo-tuong/c2784',
            'https://tiki.vn/tranh-go/c27222',
            'https://tiki.vn/tranh-son-dau/c27224',
            'https://tiki.vn/tranh-son-dau/c27224'
            
            ]

list_page_50 = []
page_error = []

for url in list_url:
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.split('/')

    category_name = path_segments[1]
    category_id = path_segments[2][1:]

    params = {
        'limit': '40',
        'include': 'advertisement',
        'aggregations': '2',
        'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
        'category': category_id,
        'page': '1',
        'urlKey': category_name
    }

    product_data = []
    
    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)
    
    if response.status_code == 200:
        response_json = response.json()
        last_page = response_json.get('paging', {}).get('last_page')
        print('total pages', last_page)
        print('CATEGORY', category_name)
        
        if last_page == 50:
            list_page_50.append(category_name)
            continue
        
        for i in range(1, last_page + 1):
            params['page'] = i
            response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

            if response.status_code == 200:
                print('request done page', i)
                response_json = response.json()
                for record in response_json.get('data', []):
                    product_id = record.get('id')
                    product_data.append({'product_id': product_id, 'category_name': category_name, 'max_page': last_page})
            else:
                print('cannot request page', i)
                page_error.append(i)
            time.sleep(random.randrange(3, 10))

        product_df = pd.DataFrame(product_data, columns=['product_id', 'category_name', 'max_page'])
        output_file_name = f'NHA-CUA-{category_name}.csv'
        product_df.to_csv(output_file_name, index=False)
        
    else:
        print(f'Cannot request data for category {category_name}')
        page_error.append(category_name)

page_50_file = 'page50.txt'
cannot_request_page_file = 'page_error.txt'

# Open the file in append mode
with open(page_50_file, 'a') as file:
    # Write each item of the list to a separate line in the file
    file.write('\n'.join(list_page_50) + '\n')

with open(cannot_request_page_file, 'a') as file:
    # Write each item of the list to a separate line in the file
    file.write('\n'.join(page_error) + '\n')
# Out:
# total pages 36
# CATEGORY dung-cu-do-luong
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# total pages 50
# CATEGORY can-nha-bep
# total pages 50
# CATEGORY dung-cu-xay-gia
# total pages 41
# ...
