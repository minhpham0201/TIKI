# %%
import pandas as pd
import json
import requests 
import time
import random
import os
from urllib.parse import urlparse

# %% [markdown]
# # Crawl Product ID

# %%
#Define web url headers
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept':'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8,th;q=0.7,zh-CN;q=0.6,zh;q=0.5',
    'X-Guest-Token': 'Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2',
    'Connection' : 'keep-alive',
    'TE': 'Trailers'
}

# %%
#create a list of URL which is all of the sub categories within a root category. Note that if a sub category already less than 50 pages
# then I will not go deeper into its' child categories anymore

#Testing with 3 links for this new script
list_url = ['https://tiki.vn/giay-the-thao-nam-co-cao/c49622',
            'https://tiki.vn/giay-luoi-vai-nam/c49624',
            'https://tiki.vn/giay-tay-nam-khong-day/c49632'
            ]
root_category = 'GIAY-NAM'

list_page_50 = []  #this list contains URL that have more than 50 pages
for url in list_url:    #get category name and category id using urlparse lib
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.split('/')

    category_name = path_segments[1]
    category_id = path_segments[2][1:]

    product_data = []  # this list will hold data of ID, category, maximum page within category
    page_error = []    # This list will hold data of error pages that we cannot request. So that we can crawl again

    params = {                     # website url params, we will loop for different params, which means request different urls
        'limit':'40', 
        'include': 'advertisement',
        'aggregations': '2',
        'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
        'category': category_id,  # change based on category id
        'page': '1',              # I set page=1, later in the loop I will change page from 1 to last_page
        'urlKey': category_name   # change based on category name
    }
    
    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)
    last_page = response.json().get('paging').get('last_page')  # I crawl last_page from TIKI, this is important to distinguish category with less than 50 pages and category >50 pages.
    
    print('CATEGORY ', category_name)
    print('total pages',last_page)
    
    if last_page == 50:           # TIKI API only allow to show 50 pages maximum. So if category with last_page = 50, we will make another list then try to use filters to divide them.  
        list_page_50.append(url)  # Append list_page_50 the url >50 pages
        continue 
    else:
        for i in range(1, last_page + 1):   # Crawl from page 1 to last_page
            params['page'] = i              # set page param to the current crawling page
            response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

            if response.status_code == 200:
                print('request done page', i)
                for record in response.json().get('data',[]): # this to ensure an empty if get method do not get any data inside
                    product_id = record.get('id')
                    product_data.append({'product_id': product_id, 'category_name': category_name, 'max_page': last_page})
            
            else:
                retry = 0  # Count for tracking the number of retry
                max_attempts = 3
                while retry < max_attempts:
                    params = {
                        'limit': '40',
                        'include': 'advertisement',
                        'aggregations': '2',
                        'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
                        'category': category_id,
                        'page': i,
                        'urlKey': category_name
                    }
                    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

                    if response.status_code == 200: #when attempt succeed!
                        print('Request done page {} at {} attempt'.format(i,retry+1))
                        for record in response.json().get('data'):
                            product_id = record.get('id')
                            product_data.append({'product_id': product_id, 'category_name': category_name, 'max_page': last_page})
                        break  # Break the while loop early

                    # If still have error for this turn
                    retry += 1
                # Check if the last request attempt could not request any better
                if retry == max_attempts:
                    print(f'Reached the maximum number of request attempts for page {i}')
                    page_error.append([category_id, category_name, i])  #save the error page to a list
            time.sleep(random.randrange(1, 2)) #sleep for a few seconds before moving to next page

        # Export file
        product_df = pd.DataFrame(product_data,columns = ['product_id','category_name','max_page'])    # Make a dataframe of crawled ID, category_name, max_page of that category
        output_file_name = f'{root_category}-{category_name}.csv'  #Export to csv file the IDs in that category. Every sub category has a distinct file. I will finally concat later in another script
        product_df.to_csv(output_file_name)
# Out:
# CATEGORY  giay-the-thao-nam-co-cao
# total pages 22
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# CATEGORY  giay-luoi-vai-nam
# total pages 11
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# CATEGORY  giay-tay-nam-khong-day
# total pages 50

# %% [markdown]
# # Crawl ID with 50 pages more

# %%
#Define price range in order to divide category with more than 50 pages into smaller groups
price_range = [
    '500,15000', '15001,30000', '30001,50000', '50001,80000', '80001,150000',
    '150001,250000', '250001,350000', '350001,550000', '550000, 100000000'
                ]

still_50_page = []

for url in list_page_50:
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.split('/')

    category_name = path_segments[1]
    category_id = path_segments[2][1:]
    product_data = []
    for price in price_range:
        params = {
            'limit': '40',
            'include': 'advertisement',
            'aggregations': '2',
            'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
            'category': category_id,
            'page': '1',
            'urlKey': category_name,
            'price': price
        }
        
        response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

        if response.status_code == 200:
            response_json = response.json()
            last_page = response_json.get('paging', {}).get('last_page')
            print('CATEGORY', category_name, 'with price range: ', price)
            print('total pages', last_page)

            if last_page == 50:
                still_50_page.append([category_name, price])
                continue
            else:
                for i in range(1, last_page + 1):
                    params['page'] = i
                    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers,params=params)

                    if response.status_code == 200:
                        print('request done page', i)
                        response_json = response.json()
                        for record in response_json.get('data', []):
                            product_id = record.get('id')
                            product_data.append({'product_id': product_id, 'category_name': category_name,
                                                 'max_page': last_page})
                    else:
                        retry = 0  # Count for tracking the number of retry
                        max_attempts = 3
                        while retry < max_attempts:
                            params = {
                                'limit': '40',
                                'include': 'advertisement',
                                'aggregations': '2',
                                'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
                                'category': category_id,
                                'page': i,
                                'urlKey': category_name
                            }
                            response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

                            if response.status_code == 200: #when attempt succeed!
                                print('Request done page {} at {} attempt'.format(i,retry+1))
                                for record in response.json().get('data'):
                                    product_id = record.get('id')
                                    product_data.append({'product_id': product_id, 'category_name': category_name, 'max_page': last_page})
                                break  # Break the while loop early

                            # If still have error for this turn
                            retry += 1
                        # Check if the last request attempt could not request any better
                        if retry == max_attempts:
                            print(f'Reached the maximum number of request attempts for page {i}')
                            page_error.append([category_id, category_name, i, price])  #save the error page to a list
                    time.sleep(1) #sleep for a few seconds before moving to next page

    # Export file
    product_df = pd.DataFrame(product_data,columns = ['product_id','category_name','max_page'])    # Make a dataframe of crawled ID, category_name, max_page of that category
    output_file_name = f'{root_category}-{category_name}.csv'  #Export to csv file the IDs in that category. Every sub category has a distinct file. I will finally concat later in another script
    product_df.to_csv(output_file_name)
# Out:
# CATEGORY giay-tay-nam-khong-day with price range:  500,15000
# total pages 1
# request done page 1
# CATEGORY giay-tay-nam-khong-day with price range:  15001,30000
# total pages 1
# request done page 1
# CATEGORY giay-tay-nam-khong-day with price range:  30001,50000
# total pages 1
# request done page 1
# CATEGORY giay-tay-nam-khong-day with price range:  50001,80000
# total pages 1
# request done page 1
# CATEGORY giay-tay-nam-khong-day with price range:  80001,150000
# total pages 3
# request done page 1
# request done page 2
# request done page 3
# CATEGORY giay-tay-nam-khong-day with price range:  150001,250000
# total pages 26
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# CATEGORY giay-tay-nam-khong-day with price range:  250001,350000
# total pages 4
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# CATEGORY giay-tay-nam-khong-day with price range:  350001,550000
# total pages 13
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13

# %% [markdown]
# # PRODUCT INFO CRAWL

# %%
def product_parser(json):
    pInfo = {}

    pInfo['id'] = json.get('id')
    pInfo['sku'] = json.get('sku')
    pInfo['name'] = json.get('name')
    pInfo['discription'] = json.get('short_description')
    pInfo['original_price'] = json.get('original_price')
    pInfo['list_price'] = json.get('list_price')
    pInfo['price'] = json.get('price')
    pInfo['alltime_quantity_sold'] = json.get('all_time_quantity_sold',{})
    pInfo['quantity_sold'] = json.get('quantity_sold', {}).get('value')
    pInfo['inventory_status'] = json.get('inventory_status')
    pInfo['fulfillment_type'] = json.get('inventory', {}).get('fulfillment_type')
    pInfo['brand'] = json.get('brand', {}).get('name')
    pInfo['category_id'] = json.get('categories', {}).get('id')
    pInfo['category'] = json.get('categories').get('name')
    pInfo['review_count'] = json.get('review_count')
    pInfo['rating_average'] = json.get('rating_average')
    pInfo['favourite_count'] = json.get('favourite_count')
    pInfo['ASA_cashback'] = json.get('asa_cashback_widget', {}).get('text')
    pInfo['pay_later'] = json.get('installment_info_v2',{})
    pInfo['current_seller'] = json.get('current_seller', {}).get('name')
    pInfo['date_created'] = json.get('day_ago_created')
    pInfo['video_url'] = json.get('video_url',{})
    
    images = json.get('images')
    if images:
        max_key = len(images)
        pInfo['max_image_key'] = max_key
    
    return pInfo

# %%
folder = r'D:\TIKI\New_crawling_optimized\GIAY-NAM'
category_list = []

# Begin to merge all csv files in the root folder into a long list of all IDs within category
for file_name in os.listdir(folder):
    file_path = os.path.join(folder,file_name)
    id_list = pd.read_csv(file_path,usecols=['product_id','category_name'])
    category_list.append(id_list)

category_list_df = pd.concat(category_list)
category_list_df = category_list_df.drop_duplicates()   # Drop duplicates IDs

# %%
#Finalize the list of all IDs and print the total number of IDs inside that root category
category_list_final = category_list_df['product_id'].to_list()
print(len(category_list_final))
# Out:
# 2994

# %%
# Define header and param for product info crawling
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept':'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8,th;q=0.7,zh-CN;q=0.6,zh;q=0.5',
    'X-Guest-Token': 'Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2',
    'Connection' : 'keep-alive',
    'TE': 'Trailers'
}

params = {
    'limit':'5',
    'include': 'comments,contribute_info,attribute_vote_summary',
}

# %% [markdown]
# - After several conducts, I see that TIKI API will block requests for about 20-30seconds for every 120 IDs being crawled. Therefore I should pause for that period.
# - To prevent this. I optimize by introducing a pause after 120 IDs break,
#
# In the last conduct, if I just crawl from the first to the last ID, I crawled 2994 IDs for 31m15s.
# Let's see if this new method could reduce time

# %%
import time

product_info = []   # make a list to store product data
error_list = []     # a list to store IDs that get error

for id in category_list_final:   # Iterate through the list of IDs crawled before  
    try:
        response = requests.get('https://tiki.vn/api/v2/products/{}'.format(id), headers=headers, params=params)
        if response.status_code == 200:
            print('crawling product id {}'.format(id))
            product_info.append(product_parser(response.json()))        # Append info crawled into the list
       
    except Exception as e:
        print('An error occurred while crawling product id {}: {}'.format(id, e))
        error_list.append(id)                                           # Append the IDs that get error for next time crawling
        time.sleep(random.uniform(10, 15))                              # Pause for some period
        continue


# After crawling the whole ID list, we  crawl IDs that in error_list
while error_list:               # begin to crawl again all IDs in error_list
    error_list_remained = []    # I create a list to store the IDS that still get errors when crawling
    
    for id in error_list:
        try:
            response = requests.get('https://tiki.vn/api/v2/products/{}'.format(id), headers=headers, params=params)
            if response.status_code == 200:
                print('Succeed re-crawling product id {}'.format(id))
                product_info.append(product_parser(response.json()))
            else:
                print('cannot crawl product id {}!'.format(id))
                error_list_remained.append(id)           # Append the IDs that still get error into 'error_list_remained'
        except Exception as e:
            print('An error occurred while crawling product id {}: {}'.format(id, e))
            error_list_remained.append(id)               # Append the IDs that still get error into 'error_list_remained'
            continue

    if len(error_list_remained) == len(error_list):  #if all of the error_list IDs cannot be crawled, we will exit the loop. It means that there are something wrong with this product ID
        print('break re-crawling due to failing to crawl these ID', error_list)
        break  
        
    else:  
        error_list = error_list_remained    # Minimize the number of IDs of error_list in the while loop
        time.sleep(1)

product_info_df = pd.DataFrame(product_info)
# Out:
# crawling product id 161496880
# crawling product id 161490177
# crawling product id 101291470
# crawling product id 199104164
# crawling product id 101292156
# crawling product id 208601178
# crawling product id 182317830
# crawling product id 185146153
# crawling product id 225947937
# crawling product id 199103927
# crawling product id 168953188
# crawling product id 168946336
# crawling product id 199104161
# crawling product id 199104159
# crawling product id 4017903
# crawling product id 191908085
# crawling product id 153259212
# crawling product id 190195327
# crawling product id 106320873
# crawling product id 199104094
# crawling product id 199104089
# crawling product id 115241354
# crawling product id 132372284
# crawling product id 191907702
# crawling product id 100420464
# crawling product id 125779590
# crawling product id 176254517
# crawling product id 182124443
# crawling product id 193736063
# crawling product id 208017588
# crawling product id 242715109
# crawling product id 153257484
# crawling product id 152347892
# crawling product id 153257608
# crawling product id 174182231
# crawling product id 157078827
# crawling product id 182301240
# crawling product id 84760739
# crawling product id 187558929
# crawling product id 21079288
# crawling product id 152348524
# crawling product id 181467109
# crawling product id 208365804
# crawling product id 185123649
# crawling product id 199102744
# crawling product id 9810961
# crawling product id 73862921
# crawling product id 101292329
# crawling product id 101292445
# crawling product id 177055103
# crawling product id 208364729
# crawling product id 198876028
# crawling product id 9810794
# crawling product id 76826784
# crawling product id 182805051
# crawling product id 208364733
# crawling product id 11502031
# crawling product id 208364917
# crawling product id 260185612
# crawling product id 193736041
# crawling product id 105522073
# crawling product id 242706464
# crawling product id 110850786
# crawling product id 121309092
# crawling product id 3631611
# crawling product id 9810736
# crawling product id 208366011
# crawling product id 4167621
# crawling product id 172430070
# crawling product id 120386847
# crawling product id 247944872
# crawling product id 114626043
# crawling product id 208431665
# crawling product id 208365891
# crawling product id 208362903
# crawling product id 136153395
# crawling product id 208365751
# crawling product id 161496598
# crawling product id 208367505
# crawling product id 127379646
# crawling product id 208364432
# crawling product id 208362929
# crawling product id 208364998
# crawling product id 174182245
# crawling product id 194182410
# crawling product id 178467712
# crawling product id 260196426
# crawling product id 101291647
# crawling product id 113045759
# crawling product id 208363201
# crawling product id 191946706
# crawling product id 174294474
# crawling product id 84760349
# crawling product id 98039697
# crawling product id 212485428
# crawling product id 98039830
# crawling product id 84760929
# crawling product id 84762432
# crawling product id 192713465
# crawling product id 76104817
# crawling product id 113046432
# crawling product id 208365995
# crawling product id 98296905
# crawling product id 242706324
# crawling product id 73888932
# crawling product id 206587010
# crawling product id 259767960
# crawling product id 242706071
# crawling product id 100420520
# crawling product id 197728660
# crawling product id 242748809
# crawling product id 113238343
# crawling product id 98296286
# crawling product id 100419689
# crawling product id 248415389
# crawling product id 3647289
# crawling product id 113451077
# crawling product id 84762214
# crawling product id 175828815
# crawling product id 248556299
# crawling product id 242748848
# crawling product id 245767205
# crawling product id 208364160
# crawling product id 212485387
# crawling product id 178467057
# crawling product id 208364101
# crawling product id 84762070
# crawling product id 163135252
# crawling product id 208366493
# crawling product id 84763940
# crawling product id 110448724
# crawling product id 206587493
# crawling product id 149780748
# crawling product id 150945929
# crawling product id 84761173
# crawling product id 84761100
# crawling product id 84763202
# crawling product id 132080323
# crawling product id 125411945
# crawling product id 153257375
# crawling product id 249602431
# An error occurred while crawling product id 249602431: Expecting value: line 1 column 1 (char 0)
# crawling product id 201657382
# An error occurred while crawling product id 201657382: Expecting value: line 1 column 1 (char 0)
# crawling product id 132080569
# crawling product id 110859727
# crawling product id 176701174
# crawling product id 26142706
# crawling product id 212485403
# crawling product id 187558611
# crawling product id 132080380
# crawling product id 186068890
# crawling product id 137752762
# crawling product id 186067553
# crawling product id 193760598
# crawling product id 132078566
# crawling product id 101291936
# crawling product id 152347537
# crawling product id 72742868
# crawling product id 114415947
# crawling product id 242748886
# crawling product id 257996569
# crawling product id 199104008
# crawling product id 199104011
# crawling product id 101291412
# crawling product id 244690440
# crawling product id 139211413
# crawling product id 208366356
# crawling product id 242705872
# crawling product id 177374075
# crawling product id 178057737
# crawling product id 151921407
# crawling product id 249237715
# crawling product id 110432016
# crawling product id 132372006
# crawling product id 135639389
# crawling product id 206587039
# crawling product id 104337981
# crawling product id 242983214
# crawling product id 37906083
# crawling product id 198425286
# crawling product id 249237695
# crawling product id 186817929
# crawling product id 128268852
# crawling product id 184762771
# crawling product id 157599289
# crawling product id 84762127
# crawling product id 187558891
# crawling product id 216217418
# crawling product id 112696232
# crawling product id 197728775
# crawling product id 84761567
# crawling product id 129945276
# crawling product id 191907791
# crawling product id 216253228
# crawling product id 215040349
# crawling product id 164024416
# crawling product id 24746221
# crawling product id 216251983
# crawling product id 208364028
# crawling product id 193736056
# crawling product id 135639560
# crawling product id 199103899
# crawling product id 191907936
# crawling product id 132371958
# crawling product id 101291549
# crawling product id 187558679
# crawling product id 187558285
# crawling product id 152345408
# crawling product id 177446070
# crawling product id 129943954
# crawling product id 242703787
# crawling product id 178466308
# crawling product id 125411881
# crawling product id 200952663
# crawling product id 114207259
# crawling product id 208364133
# crawling product id 262286631
# crawling product id 216252766
# crawling product id 198359264
# crawling product id 199103982
# crawling product id 112928061
# crawling product id 59375420
# crawling product id 208366557
# crawling product id 216252363
# crawling product id 197727597
# crawling product id 197729829
# crawling product id 221276776
# crawling product id 175828799
# crawling product id 248715672
# crawling product id 257861931
# crawling product id 251750509
# crawling product id 205276268
# crawling product id 148677747
# crawling product id 197729780
# crawling product id 152347711
# crawling product id 180932122
# crawling product id 262252834
# crawling product id 217719128
# crawling product id 206135210
# crawling product id 206587678
# crawling product id 206587397
# crawling product id 191907994
# crawling product id 178466362
# crawling product id 178465814
# crawling product id 93268793
# crawling product id 37908173
# crawling product id 143644274
# crawling product id 248612303
# crawling product id 187558507
# crawling product id 24457583
# crawling product id 208363461
# crawling product id 200952426
# crawling product id 199103858
# crawling product id 78959337
# crawling product id 170068900
# crawling product id 183040324
# crawling product id 200646813
# crawling product id 174294453
# crawling product id 111725938
# crawling product id 52577805
# crawling product id 187558853
# crawling product id 181926723
# crawling product id 248716924
# crawling product id 180318456
# An error occurred while crawling product id 180318456: Expecting value: line 1 column 1 (char 0)
# crawling product id 149780222
# An error occurred while crawling product id 149780222: Expecting value: line 1 column 1 (char 0)
# crawling product id 125144886
# crawling product id 208366757
# crawling product id 174182225
# crawling product id 180931958
# crawling product id 180932043
# crawling product id 197729618
# crawling product id 37909127
# crawling product id 178466356
# crawling product id 84761984
# crawling product id 200950997
# crawling product id 244768574
# crawling product id 141011740
# crawling product id 160831156
# crawling product id 206586956
# crawling product id 200952922
# crawling product id 164254879
# crawling product id 198413083
# crawling product id 110592989
# crawling product id 152347661
# crawling product id 196247363
# crawling product id 204900520
# crawling product id 100420643
# crawling product id 125781626
# crawling product id 108456633
# crawling product id 175829165
# crawling product id 91622756
# crawling product id 257861667
# crawling product id 200952156
# crawling product id 180318887
# crawling product id 216251609
# crawling product id 113454090
# crawling product id 101291723
# crawling product id 123841235
# crawling product id 249747443
# crawling product id 178467927
# crawling product id 178057679
# crawling product id 203150672
# crawling product id 132372286
# crawling product id 216253237
# crawling product id 116021248
# crawling product id 208363139
# crawling product id 13632637
# crawling product id 135901071
# crawling product id 108141955
# crawling product id 197730149
# crawling product id 248611494
# crawling product id 248612188
# crawling product id 262076767
# crawling product id 262273513
# crawling product id 262144850
# crawling product id 262276041
# crawling product id 262251035
# crawling product id 262260393
# crawling product id 262278654
# crawling product id 262148941
# crawling product id 262144690
# crawling product id 206587264
# crawling product id 259539008
# crawling product id 197730861
# crawling product id 250493007
# crawling product id 208017306
# crawling product id 251756399
# crawling product id 216236805
# crawling product id 262264356
# crawling product id 262137331
# crawling product id 262260800
# crawling product id 216250870
# crawling product id 262244808
# crawling product id 262146323
# crawling product id 262285753
# crawling product id 263357538
# crawling product id 184761607
# crawling product id 248611814
# crawling product id 206587680
# crawling product id 251748109
# crawling product id 262519235
# crawling product id 262519647
# crawling product id 101292419
# crawling product id 216250090
# crawling product id 262281300
# crawling product id 262247131
# crawling product id 262248559
# crawling product id 216253611
# crawling product id 262261320
# crawling product id 262148072
# crawling product id 242153426
# crawling product id 242748830
# crawling product id 248611596
# crawling product id 262423396
# crawling product id 262141228
# crawling product id 262252646
# crawling product id 262237672
# crawling product id 262269653
# crawling product id 216236418
# crawling product id 262150161
# crawling product id 262216702
# crawling product id 262246764
# crawling product id 262140686
# crawling product id 262264026
# crawling product id 262252396
# crawling product id 262167307
# crawling product id 263483320
# crawling product id 206587141
# crawling product id 176701026
# crawling product id 205272270
# crawling product id 225189317
# crawling product id 249747066
# crawling product id 182744539
# crawling product id 183041996
# crawling product id 259534588
# crawling product id 202034978
# crawling product id 252074440
# crawling product id 262519607
# crawling product id 216237972
# crawling product id 262145002
# crawling product id 262264963
# crawling product id 216235538
# crawling product id 262226495
# crawling product id 262267108
# crawling product id 216238403
# crawling product id 262287799
# An error occurred while crawling product id 262287799: Expecting value: line 1 column 1 (char 0)
# crawling product id 262283260
# crawling product id 262211051
# crawling product id 216236281
# crawling product id 251253545
# crawling product id 259563828
# crawling product id 251762445
# crawling product id 251253572
# crawling product id 252211869
# crawling product id 197730484
# crawling product id 249746214
# crawling product id 249746548
# crawling product id 242705242
# crawling product id 242153465
# crawling product id 199103925
# crawling product id 259771216
# crawling product id 199104071
# crawling product id 242748868
# crawling product id 262250503
# crawling product id 241607687
# crawling product id 262241079
# crawling product id 262230679
# crawling product id 262138771
# crawling product id 262240776
# crawling product id 216252045
# crawling product id 262284122
# crawling product id 262268815
# crawling product id 262282887
# crawling product id 249960604
# crawling product id 258231336
# crawling product id 201167849
# crawling product id 171971936
# crawling product id 201167458
# crawling product id 201167498
# crawling product id 208643167
# crawling product id 208642970
# crawling product id 208642797
# crawling product id 111986185
# crawling product id 145250808
# crawling product id 261803899
# crawling product id 111995474
# crawling product id 84761648
# crawling product id 77750031
# crawling product id 82914204
# crawling product id 46116246
# crawling product id 84760776
# crawling product id 101655800
# crawling product id 208499409
# crawling product id 84763302
# crawling product id 84760587
# crawling product id 203814590
# crawling product id 84761544
# crawling product id 203814142
# crawling product id 84761531
# crawling product id 197729262
# crawling product id 197728679
# crawling product id 132079543
# crawling product id 84762174
# crawling product id 197727480
# crawling product id 132079317
# crawling product id 132080681
# crawling product id 176896608
# crawling product id 192790516
# crawling product id 132080468
# crawling product id 178472673
# crawling product id 186907951
# crawling product id 84761994
# crawling product id 197729165
# crawling product id 84760416
# crawling product id 84763050
# crawling product id 197728820
# crawling product id 84762314
# crawling product id 84761248
# crawling product id 153259788
# crawling product id 197728896
# crawling product id 98143157
# crawling product id 84761452
# crawling product id 84761153
# crawling product id 103365855
# crawling product id 84762727
# crawling product id 186877960
# crawling product id 178954064
# crawling product id 178954164
# crawling product id 197730247
# crawling product id 196426650
# crawling product id 197730589
# crawling product id 84762425
# crawling product id 197727381
# crawling product id 197729452
# crawling product id 193760552
# crawling product id 84762068
# crawling product id 84763507
# crawling product id 84761801
# crawling product id 197730469
# crawling product id 103370189
# crawling product id 178953549
# crawling product id 132079727
# crawling product id 84761515
# crawling product id 111993472
# crawling product id 84762617
# crawling product id 84761010
# crawling product id 84760928
# crawling product id 84761941
# crawling product id 197729626
# crawling product id 186878195
# crawling product id 178954459
# crawling product id 197729944
# crawling product id 197729252
# crawling product id 111996051
# crawling product id 186877671
# crawling product id 178954394
# crawling product id 84761456
# crawling product id 178954633
# crawling product id 84761121
# crawling product id 84763243
# crawling product id 197730037
# crawling product id 84761268
# crawling product id 84760636
# crawling product id 168092877
# crawling product id 197728907
# crawling product id 242153444
# crawling product id 197730099
# An error occurred while crawling product id 197730099: Expecting value: line 1 column 1 (char 0)
# crawling product id 197728004
# crawling product id 197727889
# crawling product id 261953104
# crawling product id 197728357
# crawling product id 203921369
# crawling product id 197728425
# crawling product id 197729078
# crawling product id 219459745
# crawling product id 197730053
# crawling product id 186877344
# crawling product id 197730798
# crawling product id 197730143
# crawling product id 197730522
# crawling product id 197730466
# crawling product id 197729447
# crawling product id 203814777
# crawling product id 197727297
# crawling product id 197727851
# crawling product id 197728513
# crawling product id 198078661
# crawling product id 197730297
# crawling product id 217578189
# crawling product id 247841886
# crawling product id 197729742
# crawling product id 197727609
# crawling product id 50107109
# crawling product id 73842197
# crawling product id 206712253
# crawling product id 143935440
# crawling product id 74621200
# crawling product id 125149497
# crawling product id 115841567
# crawling product id 143232640
# crawling product id 178467657
# crawling product id 125159293
# crawling product id 97585571
# crawling product id 57661845
# crawling product id 50319114
# crawling product id 211306320
# crawling product id 88821249
# crawling product id 178466121
# crawling product id 178466056
# crawling product id 73864652
# crawling product id 125244218
# crawling product id 188206556
# crawling product id 135901643
# crawling product id 74615576
# crawling product id 73372699
# crawling product id 125244291
# crawling product id 76058847
# crawling product id 97585553
# crawling product id 109090904
# crawling product id 115840907
# crawling product id 186072035
# crawling product id 115831840
# crawling product id 174504872
# crawling product id 125244241
# crawling product id 125158874
# crawling product id 115840284
# crawling product id 170069036
# crawling product id 125159201
# crawling product id 97585552
# crawling product id 115831441
# crawling product id 38336999
# crawling product id 178466969
# crawling product id 125146680
# crawling product id 125149477
# crawling product id 105680769
# crawling product id 135848057
# crawling product id 125159788
# crawling product id 125273400
# crawling product id 115768499
# crawling product id 44069928
# crawling product id 176896705
# crawling product id 108142332
# crawling product id 180932361
# crawling product id 129407758
# crawling product id 126116603
# crawling product id 82936728
# crawling product id 108457405
# crawling product id 115726116
# crawling product id 115840951
# crawling product id 135898736
# crawling product id 125158315
# crawling product id 125146820
# crawling product id 115772691
# crawling product id 178466917
# crawling product id 125159604
# crawling product id 115841251
# crawling product id 43394542
# crawling product id 178954540
# crawling product id 125042405
# crawling product id 154274890
# crawling product id 115841021
# crawling product id 178467288
# crawling product id 143948995
# crawling product id 175798878
# crawling product id 97585643
# crawling product id 115841816
# crawling product id 125158639
# crawling product id 15789340
# crawling product id 178954232
# crawling product id 58951379
# crawling product id 125237402
# crawling product id 206710457
# crawling product id 125244050
# crawling product id 125158359
# crawling product id 115768935
# crawling product id 115772831
# crawling product id 186907596
# crawling product id 115726152
# crawling product id 108456627
# crawling product id 115726024
# crawling product id 125158447
# crawling product id 115832362
# crawling product id 176896301
# crawling product id 125158769
# crawling product id 207379506
# crawling product id 186877398
# crawling product id 125261533
# crawling product id 110267290
# An error occurred while crawling product id 110267290: Expecting value: line 1 column 1 (char 0)
# crawling product id 115772679
# crawling product id 178953742
# crawling product id 108457307
# crawling product id 38759057
# crawling product id 108141383
# crawling product id 115841552
# crawling product id 115832016
# crawling product id 115841129
# crawling product id 115769177
# crawling product id 125244179
# crawling product id 97585601
# crawling product id 97585713
# crawling product id 35407540
# crawling product id 115841909
# crawling product id 115841046
# crawling product id 186907492
# crawling product id 178954431
# crawling product id 110265673
# crawling product id 207508771
# crawling product id 115768476
# crawling product id 135898449
# crawling product id 135898547
# crawling product id 125159882
# crawling product id 207508714
# crawling product id 178467193
# crawling product id 115769055
# crawling product id 207508293
# crawling product id 135898642
# crawling product id 115841142
# crawling product id 125042575
# crawling product id 115831481
# crawling product id 88818047
# crawling product id 74285295
# crawling product id 84763364
# crawling product id 206712675
# crawling product id 175800303
# crawling product id 175797750
# crawling product id 115831903
# crawling product id 115840271
# crawling product id 88813692
# crawling product id 125147556
# crawling product id 205543202
# crawling product id 198430974
# crawling product id 110006442
# crawling product id 202332741
# crawling product id 115830634
# crawling product id 135898776
# crawling product id 135898801
# crawling product id 97585695
# crawling product id 108142607
# crawling product id 175797998
# crawling product id 135901728
# crawling product id 115830964
# crawling product id 207510927
# crawling product id 115840846
# crawling product id 178953569
# crawling product id 129407619
# crawling product id 206713006
# crawling product id 175798911
# crawling product id 178954344
# crawling product id 115831227
# crawling product id 178954514
# crawling product id 115772911
# crawling product id 135852529
# crawling product id 135901696
# crawling product id 115841466
# crawling product id 206710822
# crawling product id 125158455
# crawling product id 115831129
# crawling product id 125158476
# crawling product id 125149478
# crawling product id 125261505
# crawling product id 186878204
# crawling product id 125244034
# crawling product id 135898587
# crawling product id 198427082
# crawling product id 178465767
# crawling product id 183038717
# crawling product id 84762589
# crawling product id 110264658
# crawling product id 115831451
# crawling product id 108142861
# crawling product id 207508572
# crawling product id 125158467
# crawling product id 183042289
# crawling product id 135841782
# crawling product id 115830759
# crawling product id 115841647
# crawling product id 207510420
# crawling product id 108142220
# crawling product id 115726204
# crawling product id 135852607
# crawling product id 115831846
# crawling product id 186877872
# crawling product id 125244041
# crawling product id 97585598
# crawling product id 206711407
# crawling product id 125158543
# crawling product id 74610360
# crawling product id 110172544
# crawling product id 106786384
# crawling product id 110006269
# crawling product id 175806715
# crawling product id 207508928
# crawling product id 207379914
# crawling product id 108456679
# crawling product id 135898436
# crawling product id 108142475
# crawling product id 115769025
# crawling product id 135898346
# crawling product id 186909395
# crawling product id 135898169
# crawling product id 206710053
# crawling product id 186877992
# crawling product id 206710218
# crawling product id 125596348
# crawling product id 125158451
# crawling product id 110169382
# crawling product id 110172867
# crawling product id 171579753
# crawling product id 176896328
# An error occurred while crawling product id 176896328: Expecting value: line 1 column 1 (char 0)
# crawling product id 178467736
# crawling product id 178467689
# crawling product id 206713305
# crawling product id 125042564
# crawling product id 207510699
# crawling product id 125147691
# crawling product id 115832314
# crawling product id 125273391
# crawling product id 36340934
# crawling product id 178465812
# crawling product id 176896429
# crawling product id 178467089
# crawling product id 203984112
# crawling product id 190749351
# crawling product id 108457436
# crawling product id 206710192
# crawling product id 206712547
# crawling product id 206711890
# crawling product id 135898546
# crawling product id 207509742
# crawling product id 115831052
# crawling product id 115841559
# crawling product id 206711112
# crawling product id 135846050
# crawling product id 186909682
# crawling product id 206710843
# crawling product id 108457342
# crawling product id 125261365
# crawling product id 186878266
# crawling product id 178953753
# crawling product id 207509658
# crawling product id 108456669
# crawling product id 115769150
# crawling product id 125158868
# crawling product id 115832015
# crawling product id 206710324
# crawling product id 206712032
# crawling product id 125159125
# crawling product id 125159237
# crawling product id 135901672
# crawling product id 207509575
# crawling product id 175800512
# crawling product id 207509725
# crawling product id 206711525
# crawling product id 125158601
# crawling product id 174507578
# crawling product id 197214155
# crawling product id 110170886
# crawling product id 84762288
# crawling product id 108457353
# crawling product id 130832124
# crawling product id 74615376
# crawling product id 175798881
# crawling product id 108777412
# crawling product id 170069119
# crawling product id 115831244
# crawling product id 186907378
# crawling product id 207383266
# crawling product id 125931327
# crawling product id 186877423
# crawling product id 115832157
# crawling product id 207510801
# crawling product id 108142582
# crawling product id 125158429
# crawling product id 207509912
# crawling product id 115768931
# crawling product id 175797857
# crawling product id 115841017
# crawling product id 125042479
# crawling product id 115841881
# crawling product id 115841491
# crawling product id 125042452
# crawling product id 115841030
# crawling product id 135852542
# crawling product id 115840706
# crawling product id 115831430
# crawling product id 186877733
# crawling product id 186907595
# crawling product id 125158465
# crawling product id 186907645
# crawling product id 115726025
# crawling product id 115841168
# crawling product id 186874799
# crawling product id 115772681
# crawling product id 207510818
# crawling product id 125159875
# crawling product id 115842003
# crawling product id 115832155
# crawling product id 186877764
# crawling product id 115831399
# crawling product id 186909769
# crawling product id 88818256
# crawling product id 115830885
# crawling product id 115775121
# crawling product id 125158056
# crawling product id 125147295
# crawling product id 108457282
# crawling product id 115831696
# crawling product id 110267826
# crawling product id 176896414
# crawling product id 84760883
# crawling product id 203984368
# crawling product id 252068638
# crawling product id 178467093
# crawling product id 88818455
# crawling product id 178467321
# crawling product id 206712995
# crawling product id 186907597
# crawling product id 115831850
# crawling product id 115772712
# crawling product id 115831849
# crawling product id 125932077
# crawling product id 115831390
# crawling product id 125147275
# crawling product id 206710529
# crawling product id 175797816
# crawling product id 115772950
# crawling product id 125159332
# crawling product id 206711942
# crawling product id 115841530
# crawling product id 115840944
# An error occurred while crawling product id 115840944: Expecting value: line 1 column 1 (char 0)
# crawling product id 115772973
# crawling product id 178954746
# crawling product id 186877425
# crawling product id 167939753
# crawling product id 206710805
# crawling product id 167931790
# crawling product id 135898074
# crawling product id 125273321
# crawling product id 186907892
# crawling product id 207509723
# crawling product id 206710216
# crawling product id 207509067
# crawling product id 186874868
# crawling product id 135845762
# crawling product id 207509542
# crawling product id 115831018
# crawling product id 178954552
# crawling product id 125261466
# crawling product id 125273366
# crawling product id 97585593
# crawling product id 97585652
# crawling product id 178466506
# crawling product id 110266159
# crawling product id 178468136
# crawling product id 108928103
# crawling product id 178467426
# crawling product id 179780419
# crawling product id 178466158
# crawling product id 178466654
# crawling product id 178466450
# crawling product id 175798940
# crawling product id 125160038
# crawling product id 125159939
# crawling product id 125158130
# crawling product id 125158668
# crawling product id 124934923
# crawling product id 207508522
# crawling product id 186877380
# crawling product id 135845850
# crawling product id 115841232
# crawling product id 115841767
# crawling product id 207508136
# crawling product id 115832303
# crawling product id 175797906
# crawling product id 186909792
# crawling product id 125158140
# crawling product id 115831987
# crawling product id 135846101
# crawling product id 108143005
# crawling product id 115832046
# crawling product id 125159248
# crawling product id 135840032
# crawling product id 207509922
# crawling product id 186878663
# crawling product id 135852453
# crawling product id 135840051
# crawling product id 125237508
# crawling product id 88821197
# crawling product id 125273317
# crawling product id 125261357
# crawling product id 125596450
# crawling product id 97585634
# crawling product id 206710922
# crawling product id 125159378
# crawling product id 125159862
# crawling product id 207385187
# crawling product id 176896373
# crawling product id 182708585
# crawling product id 176896572
# crawling product id 205478939
# crawling product id 115831661
# crawling product id 179764679
# crawling product id 177929065
# crawling product id 206712278
# crawling product id 206712766
# crawling product id 207507661
# crawling product id 115831992
# crawling product id 207508278
# crawling product id 186877653
# crawling product id 115772674
# crawling product id 115726144
# crawling product id 125158186
# crawling product id 186909859
# crawling product id 108457213
# crawling product id 186878532
# crawling product id 178953487
# crawling product id 135844482
# crawling product id 206711825
# crawling product id 115830656
# crawling product id 108141219
# crawling product id 207507637
# crawling product id 115726023
# crawling product id 115772758
# crawling product id 125159880
# crawling product id 115775195
# crawling product id 135840037
# crawling product id 135898610
# crawling product id 125271618
# crawling product id 97585555
# crawling product id 97585673
# crawling product id 125243978
# crawling product id 175806607
# crawling product id 207379770
# crawling product id 186878089
# crawling product id 178466111
# crawling product id 160830566
# crawling product id 178466518
# crawling product id 178466784
# crawling product id 3712271
# crawling product id 110171169
# crawling product id 49320645
# crawling product id 206712679
# crawling product id 206711400
# crawling product id 175799148
# crawling product id 158756844
# crawling product id 135901833
# crawling product id 206712068
# crawling product id 108457206
# crawling product id 207508814
# crawling product id 175800566
# crawling product id 115841622
# An error occurred while crawling product id 115841622: Expecting value: line 1 column 1 (char 0)
# crawling product id 207509346
# crawling product id 207510460
# crawling product id 135897241
# crawling product id 207508858
# crawling product id 186907782
# crawling product id 115840834
# crawling product id 186878664
# crawling product id 206710711
# crawling product id 207508519
# crawling product id 108141506
# crawling product id 115831224
# crawling product id 186907537
# crawling product id 115830749
# crawling product id 186878604
# crawling product id 115840971
# crawling product id 115726022
# crawling product id 135898681
# crawling product id 186907631
# crawling product id 175800331
# crawling product id 125042586
# crawling product id 206711951
# crawling product id 125158790
# crawling product id 178954797
# crawling product id 115832111
# crawling product id 108457329
# crawling product id 167939799
# crawling product id 125236308
# crawling product id 125273421
# crawling product id 125273447
# crawling product id 178954148
# crawling product id 186878130
# crawling product id 108457211
# crawling product id 186878435
# crawling product id 125158450
# crawling product id 186909813
# crawling product id 125158828
# crawling product id 125271435
# crawling product id 125261459
# crawling product id 108457239
# crawling product id 135846071
# crawling product id 115772663
# crawling product id 178953514
# crawling product id 135840113
# crawling product id 115841191
# crawling product id 135840173
# crawling product id 135846070
# crawling product id 186878358
# crawling product id 115726095
# crawling product id 75630719
# crawling product id 108457243
# crawling product id 175806631
# crawling product id 113366491
# crawling product id 135898258
# crawling product id 186909600
# crawling product id 115772775
# crawling product id 135898025
# crawling product id 115841024
# crawling product id 135898933
# crawling product id 125146796
# crawling product id 186907482
# crawling product id 88817998
# crawling product id 178954712
# crawling product id 84761044
# crawling product id 115726219
# crawling product id 115726093
# crawling product id 125158421
# crawling product id 175797846
# crawling product id 175800302
# crawling product id 178954559
# crawling product id 115768968
# crawling product id 115830626
# crawling product id 135897357
# crawling product id 125159101
# crawling product id 135846366
# crawling product id 115841868
# crawling product id 135840098
# crawling product id 125244055
# crawling product id 88818733
# crawling product id 125261445
# crawling product id 180931990
# crawling product id 175799146
# crawling product id 135898259
# crawling product id 115841768
# crawling product id 125042530
# crawling product id 175800380
# crawling product id 135840174
# crawling product id 135852518
# crawling product id 186909556
# crawling product id 135848076
# crawling product id 135898136
# crawling product id 115726150
# crawling product id 108457303
# crawling product id 125236257
# crawling product id 178954771
# crawling product id 135901631
# crawling product id 108457447
# crawling product id 186877721
# crawling product id 180932105
# crawling product id 180932232
# crawling product id 178466080
# crawling product id 115775169
# crawling product id 125158180
# crawling product id 115841894
# crawling product id 186878011
# crawling product id 115832029
# crawling product id 115772791
# crawling product id 168092956
# crawling product id 178954269
# crawling product id 115769074
# crawling product id 125159164
# crawling product id 125160044
# crawling product id 125159115
# crawling product id 135898405
# crawling product id 135840020
# crawling product id 125159428
# crawling product id 175806453
# crawling product id 178954346
# crawling product id 178953599
# crawling product id 115772780
# crawling product id 115726155
# crawling product id 135898619
# An error occurred while crawling product id 135898619: Expecting value: line 1 column 1 (char 0)
# crawling product id 186877900
# crawling product id 125159982
# crawling product id 175806476
# crawling product id 135898486
# crawling product id 167931405
# crawling product id 145277509
# crawling product id 206713154
# crawling product id 206713085
# crawling product id 206712839
# crawling product id 206712735
# crawling product id 206713259
# crawling product id 206712619
# crawling product id 206711651
# crawling product id 206712416
# crawling product id 206710104
# crawling product id 206711237
# crawling product id 206712707
# crawling product id 206711043
# crawling product id 207508292
# crawling product id 207508911
# crawling product id 206710033
# crawling product id 207385731
# crawling product id 207509684
# crawling product id 207509801
# crawling product id 207379902
# crawling product id 207509400
# crawling product id 207508841
# crawling product id 207510570
# crawling product id 207507934
# crawling product id 207507913
# crawling product id 206712074
# crawling product id 207511079
# crawling product id 207508036
# crawling product id 207507893
# crawling product id 207510254
# crawling product id 178954086
# crawling product id 207509137
# crawling product id 125244029
# crawling product id 186878051
# crawling product id 206710299
# crawling product id 207507533
# crawling product id 207508741
# crawling product id 206712217
# crawling product id 125160057
# crawling product id 206711068
# crawling product id 207508595
# crawling product id 207508152
# crawling product id 206712088
# crawling product id 206711606
# crawling product id 135898861
# crawling product id 207510139
# crawling product id 207380022
# crawling product id 207507892
# crawling product id 207508803
# crawling product id 207511111
# crawling product id 206710038
# crawling product id 207507610
# crawling product id 207509099
# crawling product id 207509244
# crawling product id 125146526
# crawling product id 207386086
# crawling product id 165652729
# crawling product id 206713292
# crawling product id 206710183
# crawling product id 206712408
# crawling product id 206710424
# crawling product id 206710043
# crawling product id 206713209
# crawling product id 206710948
# crawling product id 206711697
# crawling product id 206710026
# crawling product id 206713180
# crawling product id 206711495
# crawling product id 206712490
# crawling product id 206710957
# crawling product id 206712791
# crawling product id 206712792
# crawling product id 206711931
# crawling product id 206711772
# crawling product id 178953843
# crawling product id 206711804
# crawling product id 207507456
# crawling product id 206711713
# crawling product id 207510790
# crawling product id 125146480
# crawling product id 206711467
# crawling product id 207509105
# crawling product id 207508697
# crawling product id 207510465
# crawling product id 207509680
# crawling product id 115772689
# crawling product id 178953856
# crawling product id 207509417
# crawling product id 207509556
# crawling product id 207509757
# crawling product id 206712091
# crawling product id 207507812
# crawling product id 186878650
# crawling product id 206710935
# crawling product id 207509797
# crawling product id 175806605
# crawling product id 207508440
# crawling product id 207509975
# crawling product id 206712171
# crawling product id 206711473
# crawling product id 206711150
# crawling product id 206710874
# crawling product id 186878180
# crawling product id 206711833
# crawling product id 207509930
# crawling product id 207511067
# crawling product id 207508906
# crawling product id 206711398
# crawling product id 206711703
# crawling product id 206710265
# crawling product id 186878138
# crawling product id 206710504
# crawling product id 207510823
# crawling product id 207510978
# crawling product id 207510359
# crawling product id 125159573
# An error occurred while crawling product id 125159573: Expecting value: line 1 column 1 (char 0)
# crawling product id 207507454
# An error occurred while crawling product id 207507454: Expecting value: line 1 column 1 (char 0)
# crawling product id 207508396
# crawling product id 207379586
# crawling product id 206710665
# crawling product id 207510231
# crawling product id 206711968
# crawling product id 206711612
# crawling product id 115831901
# crawling product id 207509382
# crawling product id 186877913
# crawling product id 207507983
# crawling product id 206711346
# crawling product id 207510047
# crawling product id 207385742
# crawling product id 249744851
# crawling product id 206709932
# crawling product id 206712876
# crawling product id 206710769
# crawling product id 206712307
# crawling product id 206712092
# crawling product id 206710996
# crawling product id 206713087
# crawling product id 206710569
# crawling product id 206710526
# crawling product id 206712769
# crawling product id 206712506
# crawling product id 206709982
# crawling product id 206712602
# crawling product id 206712892
# crawling product id 206713034
# crawling product id 207379499
# crawling product id 207510873
# crawling product id 207383007
# crawling product id 206710132
# crawling product id 207508481
# crawling product id 207385919
# crawling product id 206711781
# crawling product id 207385756
# crawling product id 207510099
# crawling product id 206711295
# crawling product id 207510793
# crawling product id 207509371
# crawling product id 207509892
# crawling product id 207385232
# crawling product id 207508171
# crawling product id 207510391
# crawling product id 207507919
# crawling product id 186907640
# crawling product id 206711529
# crawling product id 207507774
# crawling product id 207385992
# crawling product id 206710380
# crawling product id 207507953
# crawling product id 206711219
# crawling product id 207511092
# crawling product id 206710271
# crawling product id 207379858
# crawling product id 186910096
# crawling product id 207381595
# crawling product id 207509040
# crawling product id 207509666
# crawling product id 207508160
# crawling product id 207379423
# crawling product id 207509378
# crawling product id 207508907
# crawling product id 207379548
# crawling product id 207508443
# crawling product id 186877797
# crawling product id 186907781
# crawling product id 207508827
# crawling product id 206709564
# crawling product id 207508339
# crawling product id 207508486
# crawling product id 206711877
# crawling product id 207509269
# crawling product id 207510921
# crawling product id 207510352
# crawling product id 207507885
# crawling product id 207510788
# crawling product id 178954119
# crawling product id 186878575
# crawling product id 207383174
# crawling product id 197728726
# crawling product id 197730257
# crawling product id 191820392
# crawling product id 206712949
# crawling product id 206712932
# crawling product id 206712902
# crawling product id 206711581
# crawling product id 206713071
# crawling product id 206711787
# crawling product id 206712828
# crawling product id 206710954
# crawling product id 206712744
# crawling product id 206712863
# crawling product id 206713157
# crawling product id 206711362
# crawling product id 206712249
# crawling product id 206712662
# crawling product id 206711133
# crawling product id 206711301
# crawling product id 206713185
# crawling product id 206712259
# crawling product id 206711018
# crawling product id 262779879
# crawling product id 207510707
# crawling product id 206710221
# crawling product id 207509290
# crawling product id 207508390
# crawling product id 206712172
# crawling product id 206711725
# crawling product id 206711217
# crawling product id 207510318
# crawling product id 206711266
# crawling product id 207509608
# crawling product id 207510693
# crawling product id 207508087
# crawling product id 207509864
# crawling product id 207509435
# crawling product id 206711130
# crawling product id 125146604
# crawling product id 207510583
# An error occurred while crawling product id 207510583: Expecting value: line 1 column 1 (char 0)
# crawling product id 207508502
# crawling product id 207508172
# crawling product id 207510623
# crawling product id 108457383
# crawling product id 207508534
# crawling product id 206711265
# crawling product id 207511246
# crawling product id 206711136
# crawling product id 186878482
# crawling product id 207509090
# crawling product id 207510470
# crawling product id 207508680
# crawling product id 207508360
# crawling product id 206710328
# crawling product id 207507730
# crawling product id 207510448
# crawling product id 206712081
# crawling product id 207508856
# crawling product id 207509699
# crawling product id 207510315
# crawling product id 207508998
# crawling product id 115832161
# crawling product id 186907726
# crawling product id 207510205
# crawling product id 206710281
# crawling product id 207508003
# crawling product id 186877714
# crawling product id 125596448
# crawling product id 186878201
# crawling product id 207508673
# crawling product id 207384080
# crawling product id 207379395
# crawling product id 125237496
# crawling product id 186877633
# crawling product id 206710792
# crawling product id 207383215
# crawling product id 206712198
# crawling product id 207510538
# crawling product id 207381791
# crawling product id 183038536
# crawling product id 202332499
# crawling product id 206711343
# crawling product id 206712966
# crawling product id 206710326
# crawling product id 206712594
# crawling product id 206710269
# crawling product id 206711889
# crawling product id 206709948
# crawling product id 206712523
# crawling product id 206712650
# crawling product id 206712526
# crawling product id 206712444
# crawling product id 206711961
# crawling product id 206712580
# crawling product id 206712987
# crawling product id 206713275
# crawling product id 206710799
# crawling product id 207507880
# crawling product id 206710715
# crawling product id 206712051
# crawling product id 207508319
# crawling product id 207509803
# crawling product id 207510241
# crawling product id 207509960
# crawling product id 207508726
# crawling product id 207510230
# crawling product id 186878158
# crawling product id 207507999
# crawling product id 206711418
# crawling product id 207508678
# crawling product id 206711677
# crawling product id 207379897
# crawling product id 206711496
# crawling product id 206710626
# crawling product id 207510601
# crawling product id 207507781
# crawling product id 108142293
# crawling product id 207510837
# crawling product id 178953491
# crawling product id 207509501
# crawling product id 207509160
# crawling product id 207509484
# crawling product id 186877667
# crawling product id 207510453
# crawling product id 207508311
# crawling product id 207509576
# crawling product id 207508216
# crawling product id 207508605
# crawling product id 207507564
# crawling product id 207509276
# crawling product id 206711154
# crawling product id 206711041
# crawling product id 207509048
# crawling product id 186878468
# crawling product id 207511271
# crawling product id 207508849
# crawling product id 207510080
# crawling product id 207379422
# crawling product id 247250848
# crawling product id 183042198
# crawling product id 208017522
# crawling product id 204663999
# crawling product id 249748519
# crawling product id 206711320
# crawling product id 206713130
# crawling product id 206710749
# crawling product id 206711613
# crawling product id 206711977
# crawling product id 206712717
# crawling product id 206712321
# crawling product id 206710141
# crawling product id 206712992
# crawling product id 206712570
# crawling product id 206713322
# crawling product id 206712610
# crawling product id 206710597
# crawling product id 206711516
# crawling product id 206711081
# crawling product id 207509582
# crawling product id 178954219
# crawling product id 207510514
# An error occurred while crawling product id 207510514: Expecting value: line 1 column 1 (char 0)
# crawling product id 207509351
# crawling product id 125237393
# crawling product id 207509524
# crawling product id 206709614
# crawling product id 207510026
# crawling product id 206711954
# crawling product id 207508038
# crawling product id 207510549
# crawling product id 206711045
# crawling product id 115832392
# crawling product id 207508919
# crawling product id 207508977
# crawling product id 207508324
# crawling product id 207509837
# crawling product id 207509830
# crawling product id 186907937
# crawling product id 206710794
# crawling product id 207508202
# crawling product id 178953910
# crawling product id 207509770
# crawling product id 206710835
# crawling product id 125237491
# crawling product id 206710804
# crawling product id 207509377
# crawling product id 207511068
# crawling product id 207510145
# crawling product id 207510087
# crawling product id 207510302
# crawling product id 207508857
# crawling product id 186878665
# crawling product id 186878479
# crawling product id 207510948
# crawling product id 207507617
# crawling product id 207510463
# crawling product id 207508607
# crawling product id 206710496
# crawling product id 207385623
# crawling product id 207509176
# crawling product id 206710332
# crawling product id 207508846
# crawling product id 207508546
# crawling product id 206710933
# crawling product id 207510648
# crawling product id 186907481
# crawling product id 206710316
# crawling product id 207509726
# crawling product id 206710378
# crawling product id 207509986
# crawling product id 207507784
# crawling product id 207509848
# crawling product id 206710541
# crawling product id 207385181
# crawling product id 178954351
# crawling product id 88817959
# crawling product id 207382936
# crawling product id 207385134
# crawling product id 131475735
# crawling product id 248538539
# crawling product id 247888666
# crawling product id 110009297
# crawling product id 98164799
# crawling product id 100870126
# crawling product id 110011245
# crawling product id 115674590
# crawling product id 57743141
# crawling product id 173238478
# crawling product id 110010124
# crawling product id 115674016
# crawling product id 203803323
# crawling product id 158212784
# crawling product id 101656114
# crawling product id 131417359
# crawling product id 111665721
# crawling product id 42685714
# crawling product id 77579440
# crawling product id 98675051
# crawling product id 111666824
# crawling product id 99077104
# crawling product id 95856838
# crawling product id 74285550
# crawling product id 158756527
# ...
# crawling product id 202729212
# crawling product id 215079276
# crawling product id 140779799
# crawling product id 140782193
# crawling product id 140781711
# crawling product id 140787446
# crawling product id 209921157
# crawling product id 104525162
# crawling product id 104527636
# crawling product id 104521306
# crawling product id 98148687
# crawling product id 202242958
# crawling product id 185590168
# crawling product id 197727504
# crawling product id 104531852
# crawling product id 216250918
# crawling product id 216249629
# crawling product id 262271374
# crawling product id 76262156
# crawling product id 210129625
# crawling product id 203863889
# crawling product id 201508968
# crawling product id 158213586
# crawling product id 177559843
# crawling product id 248612541
# crawling product id 212269235
# crawling product id 211945883
# crawling product id 176130526
# crawling product id 98139806
# crawling product id 98147597
# crawling product id 248612534
# crawling product id 123840627
# crawling product id 123840657
# crawling product id 68657244
# crawling product id 123841567
# crawling product id 123841738
# crawling product id 123842630
# crawling product id 129942660
# crawling product id 129943190
# crawling product id 129944894
# An error occurred while crawling product id 129944894: Expecting value: line 1 column 1 (char 0)
# crawling product id 129942851
# crawling product id 213927356
# crawling product id 214101501
# crawling product id 204129143
# crawling product id 140781825
# crawling product id 140784341
# crawling product id 140788264
# crawling product id 177874611
# crawling product id 110075852
# crawling product id 215007246
# crawling product id 207773638
# crawling product id 203867403
# crawling product id 205704891
# crawling product id 173635855
# crawling product id 140786112
# crawling product id 140782457
# crawling product id 203868155
# crawling product id 198800052
# crawling product id 98147742
# crawling product id 186874855
# crawling product id 98147424
# crawling product id 104527879
# crawling product id 104520572
# crawling product id 257843882
# crawling product id 186878069
# crawling product id 149780247
# crawling product id 252760899
# crawling product id 175415638
# crawling product id 242199591
# crawling product id 165997167
# crawling product id 216249550
# crawling product id 104520714
# crawling product id 206230645
# crawling product id 177603539
# crawling product id 152294987
# crawling product id 204052400
# crawling product id 208017415
# crawling product id 183369777
# crawling product id 115668953
# crawling product id 202708954
# crawling product id 205478872
# crawling product id 70309520
# crawling product id 94464206
# crawling product id 129942808
# crawling product id 129943002
# crawling product id 129944900
# crawling product id 222716083
# crawling product id 167425047
# crawling product id 162151324
# crawling product id 210437488
# crawling product id 215013817
# crawling product id 202059573
# crawling product id 197656608
# crawling product id 140781426
# crawling product id 140786877
# crawling product id 140779161
# crawling product id 140783750
# crawling product id 199127397
# crawling product id 199049613
# crawling product id 191592567
# crawling product id 191828835
# crawling product id 104531968
# crawling product id 104526619
# crawling product id 104524729
# crawling product id 179945878
# crawling product id 242706549
# crawling product id 204643077
# crawling product id 95881731
# crawling product id 95881121
# crawling product id 203853159
# crawling product id 161979279
# crawling product id 216252018
# crawling product id 217412726
# crawling product id 211945631
# crawling product id 211945991
# crawling product id 166389140
# crawling product id 187558427
# crawling product id 98142247
# crawling product id 43114359
# crawling product id 72035235
# crawling product id 144252046
# crawling product id 174504534
# crawling product id 189136565
# crawling product id 129944020
# crawling product id 208168558
# crawling product id 215540889
# crawling product id 161842738
# crawling product id 170120462
# crawling product id 140784734
# crawling product id 140782251
# crawling product id 197667736
# crawling product id 205723085
# crawling product id 199021951
# crawling product id 140786115
# crawling product id 140789030
# crawling product id 140787925
# crawling product id 202242350
# crawling product id 98145929
# crawling product id 116274584
# crawling product id 98147625
# crawling product id 98142410
# crawling product id 197144801
# crawling product id 42899678
# crawling product id 216253799
# crawling product id 216236945
# crawling product id 145756729
# crawling product id 133813074
# crawling product id 133810009
# crawling product id 191592730
# crawling product id 262597756
# crawling product id 211945559
# crawling product id 211945459
# crawling product id 104525409
# crawling product id 90299258
# crawling product id 98139391
# crawling product id 123840735
# crawling product id 208571180
# crawling product id 123842206
# crawling product id 104531514
# crawling product id 196022799
# crawling product id 94456007
# An error occurred while crawling product id 94456007: Expecting value: line 1 column 1 (char 0)
# crawling product id 179877506
# crawling product id 129943110
# crawling product id 230041906
# crawling product id 189557811
# crawling product id 214162957
# crawling product id 202072734
# crawling product id 262897391
# crawling product id 140785667
# crawling product id 140784306
# crawling product id 140785807
# crawling product id 140788943
# crawling product id 214096915
# crawling product id 162152183
# crawling product id 193310225
# crawling product id 193315731
# crawling product id 191914725
# crawling product id 179796984
# crawling product id 202243776
# crawling product id 104525558
# crawling product id 104520539
# crawling product id 197669763
# crawling product id 133810092
# crawling product id 198296425
# crawling product id 173630815
# crawling product id 215013780
# crawling product id 91489061
# crawling product id 211945787
# crawling product id 211946146
# crawling product id 211945882
# crawling product id 123840912
# crawling product id 91489105
# crawling product id 193647601
# crawling product id 98146144
# crawling product id 41500775
# crawling product id 104528521
# crawling product id 204338031
# crawling product id 222716077
# crawling product id 214103318
# crawling product id 198320847
# crawling product id 140785076
# crawling product id 140780329
# crawling product id 140777316
# crawling product id 140784280
# crawling product id 140789532
# crawling product id 140789986
# crawling product id 140777820
# crawling product id 140783679
# crawling product id 140785221
# crawling product id 77968672
# crawling product id 104521374
# crawling product id 94456521
# crawling product id 220678497
# crawling product id 186907506
# crawling product id 104521244
# crawling product id 186909407
# crawling product id 104529812
# crawling product id 104527830
# crawling product id 175415164
# crawling product id 111985153
# crawling product id 216235670
# crawling product id 216253901
# crawling product id 111993410
# crawling product id 94456167
# crawling product id 184484566
# crawling product id 98141631
# crawling product id 94456517
# crawling product id 104521270
# crawling product id 104532469
# crawling product id 104520441
# crawling product id 104524965
# crawling product id 98137206
# crawling product id 98147946
# crawling product id 104532165
# crawling product id 104526452
# crawling product id 94455396
# crawling product id 104526247
# crawling product id 140783209
# crawling product id 104521150
# crawling product id 98139786
# crawling product id 94468358
# crawling product id 205710761
# crawling product id 261952590
# crawling product id 253348720
# crawling product id 104527993
# crawling product id 262516399
# crawling product id 248612295
# crawling product id 262450230
# crawling product id 261949461
# crawling product id 219148275
# crawling product id 98147617
# crawling product id 214602440
# crawling product id 255368249
# crawling product id 261942632
# crawling product id 263276302
# crawling product id 261945714
# crawling product id 255759537
# crawling product id 262275183
# crawling product id 216235699
# crawling product id 262219040
# crawling product id 262238659
# crawling product id 262226301
# crawling product id 262278230
# crawling product id 262139240
# crawling product id 262248902
# crawling product id 216250816
# crawling product id 262259447
# crawling product id 262099634
# crawling product id 216238455
# crawling product id 263492418
# crawling product id 263489414
# crawling product id 262144875
# crawling product id 263514117
# crawling product id 204049373
# crawling product id 104527640
# crawling product id 201072678
# crawling product id 230222917
# crawling product id 205110818
# crawling product id 255759571
# crawling product id 259535625
# crawling product id 259479689
# crawling product id 104528388
# An error occurred while crawling product id 104528388: Expecting value: line 1 column 1 (char 0)
# crawling product id 235414630
# crawling product id 98148447
# crawling product id 104529166
# crawling product id 263276266
# crawling product id 263276562
# crawling product id 262600465
# crawling product id 262211361
# crawling product id 262268491
# crawling product id 262138310
# crawling product id 262255199
# crawling product id 262273329
# crawling product id 262280560
# crawling product id 262239725
# crawling product id 104527258
# crawling product id 262267826
# crawling product id 104530863
# crawling product id 262242617
# crawling product id 262220999
# crawling product id 262243445
# crawling product id 262146639
# crawling product id 262768838
# crawling product id 263276118
# crawling product id 263560791
# crawling product id 263568285
# crawling product id 263492637
# crawling product id 204645890
# crawling product id 104529952
# crawling product id 104529744
# crawling product id 253295406
# crawling product id 204069112
# crawling product id 259563054
# crawling product id 259563638
# crawling product id 255317309
# crawling product id 104527924
# crawling product id 261957753
# crawling product id 219148240
# crawling product id 214602328
# crawling product id 263276564
# crawling product id 98141415
# crawling product id 98149072
# crawling product id 104531440
# crawling product id 98148575
# crawling product id 104528902
# crawling product id 98148298
# crawling product id 263402041
# crawling product id 262283815
# crawling product id 262146588
# crawling product id 262271580
# crawling product id 216238236
# crawling product id 262242431
# crawling product id 216236558
# crawling product id 262235188
# crawling product id 216251059
# crawling product id 262283778
# crawling product id 216236993
# crawling product id 216235583
# crawling product id 262139372
# crawling product id 262275214
# crawling product id 262231730
# crawling product id 262287072
# crawling product id 262141147
# crawling product id 262147519
# crawling product id 262147483
# crawling product id 263489521
# crawling product id 263514793
# crawling product id 201112890
# crawling product id 201112823
# crawling product id 263490330
# crawling product id 255759602
# crawling product id 259479507
# crawling product id 98147416
# crawling product id 98147263
# crawling product id 247799318
# crawling product id 261993019
# crawling product id 262450205
# crawling product id 262059330
# crawling product id 198320656
# crawling product id 255368681
# crawling product id 215539047
# crawling product id 219148245
# crawling product id 104528718
# crawling product id 98148551
# crawling product id 257844141
# crawling product id 249962136
# crawling product id 263277124
# crawling product id 262276226
# crawling product id 262272374
# crawling product id 262235592
# crawling product id 262274674
# crawling product id 262288622
# crawling product id 262141650
# crawling product id 262274802
# crawling product id 216253480
# crawling product id 262217054
# crawling product id 262274054
# crawling product id 262234209
# crawling product id 216235421
# crawling product id 262243742
# crawling product id 263357071
# crawling product id 263490407
# crawling product id 262769534
# crawling product id 263564752
# crawling product id 263276857
# crawling product id 263567943
# crawling product id 211946209
# crawling product id 251445154
# crawling product id 98148576
# crawling product id 255317276
# crawling product id 255317207
# crawling product id 205479056
# crawling product id 262061529
# crawling product id 201112586
# crawling product id 262294256
# crawling product id 202062668
# crawling product id 219148304
# crawling product id 255368065
# crawling product id 219148352
# crawling product id 98141797
# crawling product id 98141953
# crawling product id 104527558
# crawling product id 263276078
# An error occurred while crawling product id 263276078: Expecting value: line 1 column 1 (char 0)
# crawling product id 262143486
# crawling product id 262228896
# crawling product id 262143075
# crawling product id 216249192
# crawling product id 262213380
# crawling product id 262270519
# crawling product id 262233868
# crawling product id 216249779
# crawling product id 262257447
# crawling product id 262276003
# crawling product id 262230558
# crawling product id 262091848
# crawling product id 262290169
# crawling product id 262230881
# crawling product id 262140229
# crawling product id 262276224
# crawling product id 262275687
# crawling product id 262283043
# crawling product id 262279487
# crawling product id 262235775
# crawling product id 262248420
# crawling product id 262226942
# crawling product id 262266415
# crawling product id 211945964
# crawling product id 263494748
# crawling product id 263558162
# crawling product id 197777635
# crawling product id 263514325
# crawling product id 263567324
# crawling product id 255317298
# crawling product id 255317174
# crawling product id 255759508
# crawling product id 203984547
# crawling product id 98147579
# crawling product id 98148597
# crawling product id 248611641
# crawling product id 98149002
# crawling product id 202063641
# crawling product id 248835996
# crawling product id 242753384
# An error occurred while crawling product id 242753384: 'NoneType' object has no attribute 'get'
# crawling product id 201508780
# crawling product id 253128798
# crawling product id 104531290
# crawling product id 203814189
# crawling product id 262217434
# crawling product id 262230812
# crawling product id 145104401
# crawling product id 262107007
# crawling product id 262250229
# crawling product id 262248463
# crawling product id 104531784
# crawling product id 216250804
# crawling product id 262233173
# crawling product id 262234718
# crawling product id 216249414
# crawling product id 216251196
# crawling product id 262146429
# crawling product id 216236015
# crawling product id 262256530
# crawling product id 262242976
# crawling product id 263482227
# crawling product id 263373309
# crawling product id 263494048
# crawling product id 263054284
# crawling product id 149482541
# crawling product id 197544003
# Succeed re-crawling product id 249602431
# Succeed re-crawling product id 201657382
# Succeed re-crawling product id 180318456
# Succeed re-crawling product id 149780222
# Succeed re-crawling product id 262287799
# Succeed re-crawling product id 197730099
# Succeed re-crawling product id 110267290
# Succeed re-crawling product id 176896328
# Succeed re-crawling product id 115840944
# Succeed re-crawling product id 115841622
# Succeed re-crawling product id 135898619
# Succeed re-crawling product id 125159573
# Succeed re-crawling product id 207507454
# Succeed re-crawling product id 207510583
# Succeed re-crawling product id 207510514
# Succeed re-crawling product id 111671075
# Succeed re-crawling product id 164160621
# Succeed re-crawling product id 2001669
# Succeed re-crawling product id 73265713
# Succeed re-crawling product id 201809321
# Succeed re-crawling product id 102796851
# Succeed re-crawling product id 140783138
# Succeed re-crawling product id 140786817
# Succeed re-crawling product id 211945827
# Succeed re-crawling product id 129944894
# Succeed re-crawling product id 94456007
# Succeed re-crawling product id 104528388
# Succeed re-crawling product id 263276078
# Succeed re-crawling product id 242753384
# An error occurred while crawling product id 242753384: 'NoneType' object has no attribute 'get'
# Succeed re-crawling product id 242753384
# An error occurred while crawling product id 242753384: 'NoneType' object has no attribute 'get'
# break re-crawling due to failing to crawl these ID [242753384]

# %% [markdown]
# It takes 24m54s. The time for crawling reduces a little bit when I detect this pattern. The time we save is because we don't need to crawl again for a long list of page_error as the result of pausing

# %%
product_info_df.to_csv('giay-nam-info-optimized.csv')
