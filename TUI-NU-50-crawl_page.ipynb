# %%
import pandas as pd
import json
import requests 
import time
import random
import tqdm
from urllib.parse import urlparse

# %%
# cookies = {
#     '_trackity' : '74634137-8702-8b12-fe42-46a46a2a2573',
#     'TOKENS' : '{%22access_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22%2C%22expires_in%22:157680000%2C%22expires_at%22:1844582643238%2C%22guest_token%22:%22Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2%22}',
#     'delivery_zone' : 'Vk4wMzkwMDYwMDE=',
#     '_gid' : 'GA1.2.1038835342.1686902648',
#     'tiki_client_id' : '1000198359.1686902648',
#     '_gcl_au' : '1.1.712561686.1686902651',
#     '_fbp' : 'fb.1.1686902651246.1147493922',
#     '_hjFirstSeen' : '1', 
#     '_hjIncludedInSessionSample_522327' : '0', 
#     '_hjSession_522327':'eyJpZCI6IjRmYmI5NDEzLTc1MzAtNDA3Yy1iYTMyLTYzZTI4Y2MzZTA5NSIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMTksImluU2FtcGxlIjpmYWxzZX0=',
#     '_hjAbsoluteSessionInProgress' : '0',
#     '__uidac' : 'b0f5fe8e77ade31f60d53549702ce9ac',
#     '__iid' : '749', '__iid' : '749', '__su' : '0',
#     '__su':'0', '__RC' : '5', '__R' : '3',
#     '_hjSessionUser_522327':'eyJpZCI6IjFiMTI5YzM0LWE2NTItNWZmOC05NmEzLTFhY2JlOTMwZTViYyIsImNyZWF0ZWQiOjE2ODY5MDI2NTEzMDIsImV4aXN0aW5nIjp0cnVlfQ==',
#     '__tb':'0', 
#     '__IP' : '712479999',
#     'TIKI_RECOMMENDATION' : '40be1840f8c66757ac3812da38a02d7b',
#     'TKSESSID':'cf67caae16e0362971a2fe1e3367c12e',
#     '_bs':'c4f97c3c-1a3b-0d7a-f2dd-a0a3516f6617',
#     '_gat' : '1',
#     '_ga': 'GA1.2.1000198359.1686902648',
#     '__uif' :'__uid%3A3569195332985378685%7C__ui%3A1%252C5%7C__create%3A1669195332',
#     'cto_bundle':'5mSn7195TEwza3VCTEZZTk9HdWw1cSUyQkM2dGRGV0ZtUlRua1NvRjV5S2phc096S1lIVlJySjlmZkdqUVNScWNMbEdoamc0bE82czlSR0lYS1pKMU1pNk40U2lnQSUyRiUyQlBGbFJ5MXBwUUtwOW1oVUoxQm9hY1olMkZ1ZWplRzhUdThiZnNqeExlMnkyV1NyMnpBNmlJdXAwRFZvb2FsQSUzRCUzRA',
#     'amp_99d374':'Rz66229-5rdmltAOjfyUvJ...1h31jn9b2.1h31k9l0t.2j.5e.81',
#     '_ga_GSD4ETCY1D':'GS1.1.1686902651.1.1.1686903252.28.0.0'
# }


headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept':'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8,th;q=0.7,zh-CN;q=0.6,zh;q=0.5',
    'X-Guest-Token': 'Ae1PtIuUDbozkgpQ6VOW57jKqvchZxF2',
    'Connection' : 'keep-alive',
    'TE': 'Trailers'
}

# %%
list_url = ['https://tiki.vn/tui-deo-cheo-dao-pho/c49598',
            'https://tiki.vn/tui-xach-vua-va-nho/c49602',
            'https://tiki.vn/vi-dai/c49606'
]

page_error = []
price_range = [
    '500,15000', '15001,30000', '30001,50000', '50001,80000', '80001,100000', '100001,150000',
    '150001,250000', '250001,350000', '350001,550000', '550000, 100000000'
                ]
list_page_50 = []

for url in list_url:
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.split('/')

    category_name = path_segments[1]
    category_id = path_segments[2][1:]
    product_data = []
    for price in price_range:
        params = {
            'limit': '40',
            'include': 'advertisement',
            'aggregations': '2',
            'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
            'category': category_id,
            'page': '1',
            'urlKey': category_name,
            'price': price
        }
        
        response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params)

        if response.status_code == 200:
            response_json = response.json()
            last_page = response_json.get('paging', {}).get('last_page')
            print('CATEGORY', category_name, price)
            print('total pages', last_page)

            if last_page == 50:
                list_page_50.append([category_name, price])
                continue
            else:
                for i in range(1, last_page + 1):
                    params['page'] = i
                    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers,params=params)

                    if response.status_code == 200:
                        print('request done page', i)
                        response_json = response.json()
                        for record in response_json.get('data', []):
                            product_id = record.get('id')
                            product_data.append({'product_id': product_id, 'category_name': category_name,
                                                 'max_page': last_page})
                    else:
                        print('cannot request page', i)
                        page_error.append([category_name,category_id,price,i])
                    time.sleep(random.randrange(3, 10))

    product_df = pd.DataFrame(product_data, columns=['product_id', 'category_name', 'max_page'])
    output_file_name = f'TUI-NU-50-{category_name}.csv'
    product_df.to_csv(output_file_name, index=False)
# Out:
# CATEGORY tui-deo-cheo-dao-pho 500,15000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY tui-deo-cheo-dao-pho 15001,30000
# total pages 3
# request done page 1
# request done page 2
# request done page 3
# CATEGORY tui-deo-cheo-dao-pho 30001,50000
# total pages 13
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# CATEGORY tui-deo-cheo-dao-pho 50001,80000
# total pages 40
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# CATEGORY tui-deo-cheo-dao-pho 80001,100000
# total pages 32
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# cannot request page 29
# request done page 30
# request done page 31
# request done page 32
# CATEGORY tui-deo-cheo-dao-pho 100001,150000
# total pages 46
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# cannot request page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# request done page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# request done page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# request done page 41
# request done page 42
# request done page 43
# request done page 44
# request done page 45
# request done page 46
# CATEGORY tui-deo-cheo-dao-pho 150001,250000
# total pages 47
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# request done page 23
# request done page 24
# cannot request page 25
# request done page 26
# request done page 27
# request done page 28
# request done page 29
# cannot request page 30
# request done page 31
# request done page 32
# request done page 33
# request done page 34
# request done page 35
# request done page 36
# request done page 37
# request done page 38
# request done page 39
# request done page 40
# request done page 41
# request done page 42
# request done page 43
# request done page 44
# request done page 45
# request done page 46
# request done page 47
# CATEGORY tui-deo-cheo-dao-pho 250001,350000
# total pages 22
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# request done page 18
# request done page 19
# request done page 20
# request done page 21
# request done page 22
# CATEGORY tui-deo-cheo-dao-pho 350001,550000
# total pages 15
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# CATEGORY tui-xach-vua-va-nho 500,15000
# total pages 1
# request done page 1
# CATEGORY tui-xach-vua-va-nho 15001,30000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY tui-xach-vua-va-nho 30001,50000
# total pages 6
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY tui-xach-vua-va-nho 50001,80000
# total pages 11
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# CATEGORY tui-xach-vua-va-nho 80001,100000
# total pages 8
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# CATEGORY tui-xach-vua-va-nho 100001,150000
# total pages 12
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# CATEGORY tui-xach-vua-va-nho 150001,250000
# total pages 17
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# request done page 13
# request done page 14
# request done page 15
# request done page 16
# request done page 17
# CATEGORY tui-xach-vua-va-nho 250001,350000
# total pages 11
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# CATEGORY tui-xach-vua-va-nho 350001,550000
# total pages 11
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# CATEGORY vi-dai 500,15000
# total pages 1
# request done page 1
# CATEGORY vi-dai 15001,30000
# total pages 2
# request done page 1
# request done page 2
# CATEGORY vi-dai 30001,50000
# total pages 6
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY vi-dai 50001,80000
# total pages 11
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# CATEGORY vi-dai 80001,100000
# total pages 6
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# CATEGORY vi-dai 100001,150000
# total pages 9
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# CATEGORY vi-dai 150001,250000
# total pages 12
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# request done page 8
# request done page 9
# request done page 10
# request done page 11
# request done page 12
# CATEGORY vi-dai 250001,350000
# total pages 7
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# request done page 5
# request done page 6
# request done page 7
# CATEGORY vi-dai 350001,550000
# total pages 8
# request done page 1
# request done page 2
# request done page 3
# request done page 4
# cannot request page 5
# request done page 6
# request done page 7
# request done page 8

# %%
print(list_page_50)
# Out:
# []

# %%
print(page_error)
# Out:
# [['tui-deo-cheo-dao-pho', '49598', '80001,100000', 29], ['tui-deo-cheo-dao-pho', '49598', '100001,150000', 19], ['tui-deo-cheo-dao-pho', '49598', '150001,250000', 25], ['tui-deo-cheo-dao-pho', '49598', '150001,250000', 30], ['vi-dai', '49606', '350001,550000', 5]]

# %%
product_data_error = []
if len(page_error) != 0:
    for i in range(len(page_error)):
        error_page_params = {
                    'limit': '40',
                    'include': 'advertisement',
                    'aggregations': '2',
                    'trackity_id': '74634137-8702-8b12-fe42-46a46a2a2573',
                    'category': page_error[i][1],
                    'page': str(page_error[i][3]),
                    'urlKey': page_error[i][0],
                    'price': page_error[i][2]
                }

        response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers,params=error_page_params)

        if response.status_code == 200:
            print('request done page', page_error[i][0], page_error[i][3], page_error[i][2])
            response_json = response.json()
            for record in response_json.get('data', []):
                product_id = record.get('id')
                product_data_error.append({'product_id': product_id, 'category_name': page_error[i][0]})

        time.sleep(random.randrange(3, 10))

    product_df = pd.DataFrame(product_data_error, columns=['product_id', 'category_name'])
    output_file_name = f'TUI-NU-50-ERROR-{category_name}.csv'
    product_df.to_csv(output_file_name, index=False)
# Out:
# request done page tui-deo-cheo-dao-pho 29 80001,100000
# request done page tui-deo-cheo-dao-pho 19 100001,150000
# request done page tui-deo-cheo-dao-pho 25 150001,250000
# request done page tui-deo-cheo-dao-pho 30 150001,250000
# request done page vi-dai 5 350001,550000
